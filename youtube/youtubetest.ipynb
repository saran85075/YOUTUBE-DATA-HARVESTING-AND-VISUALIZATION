# %%
"AIzaSyAsZ0mb6ovbfv_OaEKd6xLqnTOxbQK2sFw"
# Out:
# 'AIzaSyAsZ0mb6ovbfv_OaEKd6xLqnTOxbQK2sFw'

# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
import certifi
import pandas as pd
import streamlit as st

# %%
from googleapiclient.discovery import build

# %%
ca = certifi.where()

client=pymongo.MongoClient("mongodb+srv://saran75400:saran@cluster0.dbr4b2s.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0",tlsCAFile=ca)
db=client["youtube_data"]

# %%
def Api_connect():
    Api_id = "AIzaSyAsZ0mb6ovbfv_OaEKd6xLqnTOxbQK2sFw"

    Api_service_name = "youtube" 
    Api_version = "v3"

    youtube = build(Api_service_name,Api_version,developerKey=Api_id)

    return youtube

youtube = Api_connect()

# %%
#channel data extraction
def get_channel_info(channel_id):
    request = youtube.channels().list(
                  part = "snippet,ContentDetails,statistics",
                  id = channel_id
    )
    response = request.execute()

    for i in response['items']:
       data = dict(Channel_Name =i['snippet']['title'],
                   Channel_id =i['id'],
                   Subscribers =i['statistics']['subscriberCount'],
                   Views =i['statistics']['viewCount'],
                   Total_Videos =i['statistics']['videoCount'],
                   Channel_Descripition =i['snippet']['description'],
                   Playlist_id =i['contentDetails']['relatedPlaylists']['uploads'])
       
       return data

# %%
get_channel_info("UC2J_VKrAzOEJuQvFFtj3KUw")
# Out:
# {'Channel_Name': 'Chennai Super Kings',
#  'Channel_id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#  'Subscribers': '3410000',
#  'Views': '676770867',
#  'Total_Videos': '1219',
#  'Channel_Descripition': 'The Official YouTube Channel of the Chennai Super Kings. #WhistlePodu #Yellove',
#  'Playlist_id': 'UU2J_VKrAzOEJuQvFFtj3KUw'}

# %%
get_channel_info("UC-mi8xUqL43BMlhvJbAf-Ew")
# Out:
# {'Channel_Name': 'Lucknow Super Giants',
#  'Channel_id': 'UC-mi8xUqL43BMlhvJbAf-Ew',
#  'Subscribers': '142000',
#  'Views': '40652443',
#  'Total_Videos': '673',
#  'Channel_Descripition': '',
#  'Playlist_id': 'UU-mi8xUqL43BMlhvJbAf-Ew'}

# %%
get_channel_info("UCEzB47eM-HZu04f4mB2nycg")
# Out:
# {'Channel_Name': 'Delhi Capitals',
#  'Channel_id': 'UCEzB47eM-HZu04f4mB2nycg',
#  'Subscribers': '948000',
#  'Views': '369503143',
#  'Total_Videos': '3644',
#  'Channel_Descripition': 'Delhi Capitals as the brand and team embodies the exuberance, excitement and attitude unique to Delhi. It is vibrant, contrasting and irresistible. The purpose is to excite the cricketing world and inspire our fans to dare to succeed. It resonates the spirit of the city, which too believes in a never say-attitude and the hunger to succeed irrespective of the challenges. The driving principle and core values for the team are courage and brilliance; honesty and pride. This Delhi team believes in teamwork and mutual respect for their players and their fans. The new look Delhi Capitals is enthusiastic, imaginative and successful. Honest in approach and keen to unleash the excitement and bring the experience closer to the fans.',
#  'Playlist_id': 'UUEzB47eM-HZu04f4mB2nycg'}

# %%
get_channel_info("UCp10aBPqcOeBbEg7d_K9SBw")
# Out:
# {'Channel_Name': 'Kolkata Knight Riders',
#  'Channel_id': 'UCp10aBPqcOeBbEg7d_K9SBw',
#  'Subscribers': '1680000',
#  'Views': '467649563',
#  'Total_Videos': '2326',
#  'Channel_Descripition': 'Welcome to the official YouTube channel of two time IPL champions in 2012 & 2014, Kolkata Knight Riders 💜 🏆\n\nHome to exclusive videos of our Knights, behind the scenes, unfiltered moments and much more!\n\n#ipl2023 #amikkr #knightsTV #KnightsinAction #Knightclub # KnightLive\n',
#  'Playlist_id': 'UUp10aBPqcOeBbEg7d_K9SBw'}

# %%
get_channel_info("UCl23mvQ3321L7zO6JyzhVmg")
# Out:
# {'Channel_Name': 'Mumbai Indians',
#  'Channel_id': 'UCl23mvQ3321L7zO6JyzhVmg',
#  'Subscribers': '4720000',
#  'Views': '2234283336',
#  'Total_Videos': '4464',
#  'Channel_Descripition': 'The official Youtube channel of Mumbai Indians for IPL & WPL | 🏆 - IPL x 5️⃣, WPL x 1️⃣ & CLT20 x 2️⃣\n',
#  'Playlist_id': 'UUl23mvQ3321L7zO6JyzhVmg'}

# %%
get_channel_info("UCCq1xDJMBRF61kiOgU90_kw")
# Out:
# {'Channel_Name': 'Royal Challengers Bengaluru',
#  'Channel_id': 'UCCq1xDJMBRF61kiOgU90_kw',
#  'Subscribers': '4210000',
#  'Views': '645954462',
#  'Total_Videos': '2628',
#  'Channel_Descripition': 'This is the official YouTube channel of the IPL team Royal Challengers Bengaluru. Enjoy behind the scenes content from the IPL tournament inside the RCB camp featuring our star players Virat Kohli, Faf du Plessis, Mohammed Siraj, Glenn Maxwell and more with our digital shows Bold Diaries, RCB Insider, Game Day, 12th Man TV and the RCB Podcast.',
#  'Playlist_id': 'UUCq1xDJMBRF61kiOgU90_kw'}

# %%
get_channel_info("UCCBe9iIoN9Ar-Elluxca-Xw")
# Out:
# {'Channel_Name': 'Gujarat Titans',
#  'Channel_id': 'UCCBe9iIoN9Ar-Elluxca-Xw',
#  'Subscribers': '574000',
#  'Views': '171002695',
#  'Total_Videos': '1012',
#  'Channel_Descripition': 'The Official Account of Gujarat Titans | IPL 2022 🏆 | #AavaDe',
#  'Playlist_id': 'UUCBe9iIoN9Ar-Elluxca-Xw'}

# %%
get_channel_info("UCvRa1LWA_-aARq1AQMC4AyA")
# Out:
# {'Channel_Name': 'PUNJAB KINGS',
#  'Channel_id': 'UCvRa1LWA_-aARq1AQMC4AyA',
#  'Subscribers': '499000',
#  'Views': '73551399',
#  'Total_Videos': '1336',
#  'Channel_Descripition': 'The official Youtube channel for Punjab Kings. Watch #PBKS inside stories, fun facts and behind the scenes content. ',
#  'Playlist_id': 'UUvRa1LWA_-aARq1AQMC4AyA'}

# %%
get_channel_info("UCkpgyRmcNy-aZFLUkKkWK4w")
# Out:
# {'Channel_Name': 'rajasthanroyals',
#  'Channel_id': 'UCkpgyRmcNy-aZFLUkKkWK4w',
#  'Subscribers': '901000',
#  'Views': '279109469',
#  'Total_Videos': '2067',
#  'Channel_Descripition': 'Welcome to the official YouTube channel of Rajasthan Royals.\n\nWinners of the IPL 2008 trophy – the inaugural edition of the Indian Premier League – this channel is the place to be if you are a fan of the Rajasthan Royals team. Get the best seat in the house to all the dressing room discussions, net sessions, and all the fun and games beyond cricket that make us a family. \n\nSo click the subscribe button to join the Royals Family, and don’t forget to wear the RR pink and blue jersey, especially when you cheer #HallaBol for the Rajasthan Royals players during the IPL matches.\n\n#RajasthanRoyals #IPLT20 #RoyalsFamily\n',
#  'Playlist_id': 'UUkpgyRmcNy-aZFLUkKkWK4w'}

# %%
get_channel_info("UCScgEv0U9Wcnk24KfAzGTXg")
# Out:
# {'Channel_Name': 'SunrisersIPL',
#  'Channel_id': 'UCScgEv0U9Wcnk24KfAzGTXg',
#  'Subscribers': '880000',
#  'Views': '163044652',
#  'Total_Videos': '1416',
#  'Channel_Descripition': 'Welcome to the Official page of SunRisers Hyderabad, the IPL franchise owned & promoted by the Sun Group.',
#  'Playlist_id': 'UUScgEv0U9Wcnk24KfAzGTXg'}

# %%
# video Extraction
def get_videos_ids(channel_id):
    video_ids=[]
    response = youtube.channels().list(id =channel_id,
                                  part = 'contentDetails').execute()
    Playlist_Id =response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token=None

    while True:     
       response1=youtube.playlistItems().list(
                                  part ='snippet',
                                  playlistId =Playlist_Id,
                                  maxResults=50,
                                  pageToken=next_page_token).execute()
       for i in range(len(response1['items'])):
          video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
       next_page_token=response1.get('nextPageToken')

       if next_page_token is None:
         break
    return video_ids

# %%
Video_Ids=get_videos_ids("UC2J_VKrAzOEJuQvFFtj3KUw")

# %%
Video_Ids
# Out:
# ['gnDsz6Wspk4',
#  'b7NnlZuexd0',
#  'pGFjLV1C2Z4',
#  'XGH-EOgVP-4',
#  'HFQ3bmji_ns',
#  'EGL8IzShpho',
#  '_xhhX8cD3zo',
#  '3fHKM4-uNao',
#  'hj_1l47f2pg',
#  'j4EIqfbwxTE',
#  'g4WSU0u7tXY',
#  'uO5014VgWPo',
#  'jKZ5f6EOWMU',
#  'EllJkaMeC_Q',
#  'ep2Yz7ftzNU',
#  'pWbG1Cd_Hto',
#  't0xUgjZHniU',
#  'Pzf4EjbWXRo',
#  'XEjKu-aqVVg',
#  '4p-tnIPxfsY',
#  'EBhH7vCVebA',
#  'ms96xx0a1r8',
#  'TJ-7DpjnISg',
#  'izlRgzThKqo',
#  'Hc3MOuBdWb0',
#  'c84eWZVfSU0',
#  'yVP8t7QP9OQ',
#  'AwNGP2xU3ZM',
#  'TG_urpttzcY',
#  'iIYYjWi7ddU',
#  'zTvgotcXJA0',
#  'kAbgU-qP55M',
#  'xZFyE0Cahc8',
#  'Z5yfXY-vsV4',
#  'YiYKe7B8K4s',
#  'u2c8rJ6ue5g',
#  '_AqgueBPzqs',
#  'u-y4NCyk_jc',
#  'NSnXuMq-x5Q',
#  '9lFJLiaaNZQ',
#  'KSi57oHpZxc',
#  '5xAq-IZLVyo',
#  'TwLZxZ3sau8',
#  'FHONe751hxk',
#  'PQBCyyzjl2g',
#  'X6hQ6i_0Oc4',
#  'pCwTUenLX18',
#  'j8J-MWgku0Q',
#  'JBqvqyc3CMs',
#  'aR2RyRpJSBg',
#  'et9fcDGvMGM',
#  '2xKKcL0LXyQ',
#  '-MigisxedXI',
#  'Ecvz_5e4A0o',
#  'WYyGn2PDHx8',
#  'nkkbsEz23yE',
#  'jWqYrI50dCM',
#  'vAvxO3uWcmw',
#  'CifFtvgIW04',
#  'FcKdz-9Br1Y',
#  'vdYId3gHYzQ',
#  'kg8kFuusL1I',
#  'KJsCG-Ho8OU',
#  'wXvNBd0J_a8',
#  'Rzvw1q7l2FA',
#  '9W4FqLKy4Gk',
#  'vBCbzWmXpcA',
#  '5UpeKysSTS4',
#  '-FzGywV6bl8',
#  '38hCJ9W5hB0',
#  'u5SGrSWwx7s',
#  'lGgMw1Cniq4',
#  'ne9u_8R8F-E',
#  'JP5_oh60rVE',
#  'MQgYm4gm1V4',
#  'xnEdfZo-2PI',
#  'DhvBzXWwR1w',
#  'zAyvCEowEnk',
#  'vjDoOlWBJp0',
#  'MRe9L6HxRvo',
#  'bwy8VYlROvc',
#  '0bmEvVq7Ws8',
#  '6ddd1yXsWK0',
#  'wJNX3ZlaUkQ',
#  'YwSJggqfPGs',
#  'Ri5Gnml8jNc',
#  'wIUTD1FTnus',
#  '8oH0atPDiwY',
#  'kZ1gzu3IxGg',
#  's-hLe2bZeRs',
#  '0xxMPPGuhL8',
#  'fha8LqqIPPw',
#  '4twOsBNsEHc',
#  'YAbB6MTV-Sw',
#  'iBUYK18u7dI',
#  '_AzP2F64qiQ',
#  'j--OAtEOFPs',
#  'uIBy9dSPJXc',
#  'c-Elhx5OyH4',
#  '7yqd_b-cSHo',
#  'PNgsFF8daGY',
#  '8hbxvnj-02E',
#  '9LxOTWZawoU',
#  'KOGmZxI9jJw',
#  '98brRsgZ5cE',
#  '8CoILI6ThNc',
#  'b3-rS0baUrA',
#  '7CsqpL0R5J0',
#  'e4yOuMhD7xY',
#  'QaxBNasNL_s',
#  'AVNLIYL23go',
#  'xWx0KTT_lYI',
#  '5ksUpqdLHfc',
#  'WB4Ml8yjC2k',
#  'rXT9J3j0mPY',
#  '98W-G7hEPvY',
#  '2jU1xTBLBGs',
#  'lqjFpog8ZcA',
#  'KVhfaeC1LN4',
#  'w1tx7gH4-2w',
#  'fx8PhBgkiv8',
#  'baLQHOTWm3o',
#  'Erkjh_RM5y0',
#  'm_wYkpVaWCs',
#  'HYzJBwP40t0',
#  '6zv8mzeqZn0',
#  'IjsR8UBoUkE',
#  'f1gnaV4sWYo',
#  '85adJ60bQqk',
#  'zdZmopaH8vA',
#  'r88fWNdYmPc',
#  'o29L2ysDYeY',
#  'DntAi1keBkg',
#  'sWldDPznq60',
#  'R6v4PyiDOMI',
#  '51BFx3J2Ru4',
#  'xlripGf89Aw',
#  'Q4wsTEV8_XM',
#  'XZ0n5vOCj6U',
#  'W4P5AyK7Ues',
#  'RtD4q4LnLUw',
#  'WxbZtVJLID4',
#  '9OPmzW31nzk',
#  'MbzuFYeq4aU',
#  'fGHl5k_PyNE',
#  'g87iuCiFM0E',
#  '1QyC0VyxjUA',
#  'JNs4p0pk8Ms',
#  'dsMLIZKIEd8',
#  'QJNsvEta0UI',
#  'iVWyETew2KM',
#  '0b6rhoi1pAQ',
#  'RF3gM9MUPwk',
#  'FCJyVOtupZg',
#  '-zEynAwpLVI',
#  '_xYIJwAgJ_k',
#  'as-5cUQfhBk',
#  'ss4vpidhoHU',
#  'mXm-VjKPd1g',
#  'k-QBfI95DT8',
#  'z4fIO1-qF5Q',
#  'AD75Jds6EfI',
#  'mh9Mqqdvs9c',
#  '6t0tazaQy5U',
#  'r7X4ww16H68',
#  'D9_FvFWvSAw',
#  '3CGVbrCOrsA',
#  'vKaEjIPEGxc',
#  '3hFftuQdwSs',
#  '2Xh24NockS4',
#  'uhOjJIS5HIQ',
#  'wleEunjXJLk',
#  'OOCfxuEmSCk',
#  'cA-U338hrdI',
#  'rFGr1pg5_Uc',
#  'PLg5FgZjVyA',
#  '3aOXY3j8YNc',
#  'g9wXiIJxxEI',
#  'qocCXT_9cRk',
#  '1olMhbW9SOs',
#  'FjsCbmIZlXQ',
#  'juAF8d1-F78',
#  '9u_qRrwyEQI',
#  'RJ8A3mjuKL0',
#  '3c5hHUIHH54',
#  'NbJ55prgmFg',
#  '4ED_zduANt4',
#  'AfPjAWSGQg4',
#  '32gL5pW-_-k',
#  'BwXrq-IXqf0',
#  'sCZHENnY7zY',
#  'WIvbZUlxepE',
#  'tzIa2UaWB7I',
#  'FFMyN80W4a4',
#  'yaDmYd_S3sY',
#  'tTGYIEgne0k',
#  'f5ZdZRGLITI',
#  'gsnoEoyZ-q8',
#  '57oNWb4w3VU',
#  'upSADORbhYM',
#  'bqv7uphvjHU',
#  'J_CHunEwzOw',
#  '5SKwEBmpC5U',
#  'y6bLkHmZrQ8',
#  '3U_NRKIeN1Y',
#  'gmlvvur17qQ',
#  '3IpaFRIs4oo',
#  'y_gyCB_dRMo',
#  'Swr7QWKme70',
#  'Rnd5dY93Qz8',
#  '93VoZeEREwM',
#  'p1iLKSUQl7c',
#  'bTgfjK2f4wk',
#  'hXpd9BhNwS8',
#  'xDmrXFdN7bQ',
#  '1d_0ntaz6j0',
#  'IDA3tvXQTbs',
#  '1sT-mWQF5MA',
#  'ZDoZWorU5YA',
#  'ydHsLlarpDc',
#  'dVfv487Kx2k',
#  'Y4dGk8R2OJw',
#  'wo04Ft7rNf4',
#  'xiPKofKE1vg',
#  'V9q-egmwWO8',
#  '18K3eMFX0UQ',
#  'QNjmoOpsKI0',
#  'RvyXWBuTq78',
#  'g7IKEDSeOlc',
#  'lN8BIsMtpF4',
#  'WoGr30SxotQ',
#  'ucDjKyRYGrg',
#  '7fHTQv8h35s',
#  'MiY0kit0Q54',
#  'TNUrTntMOR4',
#  'zRdywsfPowU',
#  'xvaJyZUz5kU',
#  'arqEP86T4kY',
#  'qedMFDc8RiE',
#  'u4XeraUoy0o',
#  'AXf8V7BGcTk',
#  'vyNdxDJAGlE',
#  'QTmv2tm2rzs',
#  'ru5CSzUKISM',
#  'StkVy1VFNuI',
#  'JwKjneYoSsw',
#  'mwz3rMng1Hc',
#  'lL1Xebpm4yU',
#  '_nv3DgM7ipU',
#  'ld1eHFTR87k',
#  'RS60IHtnQTM',
#  'nmmVTsvr1mU',
#  '_K8aUftJPPs',
#  '-Yq6Oe63SUw',
#  'DHcO3jnGDXk',
#  'vZzEz5W9TZ0',
#  'ngIDoq6AwXA',
#  'N7vqIztpMqw',
#  'd_6C7Dq4rbE',
#  '65Ti4D_qxGU',
#  'zRMBPbHsQbc',
#  'Xsycym_Cb4M',
#  'TWPnIdMOyWM',
#  'E33rwNZLpu8',
#  'QWid9KyVLbk',
#  'DL0PNSOnFtQ',
#  'kmJU86g2ilg',
#  'pRTdN1cB_Yc',
#  'wW6wErwjsYc',
#  'a5CPMtVkeZ4',
#  'G0snaLva1-c',
#  'hSg65bbNsc4',
#  'GJ-F3UWOWr4',
#  'wsA82A_AN48',
#  'xuXWyi_P_MQ',
#  'jtNtRKigrC8',
#  'iPrmKZ0vuEw',
#  'jCQOtcW17Lw',
#  'SG3rNQRRhMM',
#  'dLoMcfl1Yvk',
#  'gaHTNiYyj8g',
#  'HkIwN7ffxX4',
#  'dsKGireGzzE',
#  'sdKQ2fqzzTc',
#  'jcFwyouLC7c',
#  '3pYJzfrjNok',
#  'vkp9-msqAfw',
#  'fBJ3tV9yVHc',
#  '8ec0Scm1IeQ',
#  'CvDuLF6dEn8',
#  'Fig96tiS-4k',
#  'ZUiywa4eAq4',
#  'Sp2i1BpmMIc',
#  'kQXt2rpukd0',
#  'rn_3nFKbbtI',
#  'U8sxk1FXkn8',
#  'O7UcgtW_qXY',
#  'cN4mvkJj8sY',
#  '-jthfYuO_98',
#  'PnqCJphMUdI',
#  'IkE_u7hWu1A',
#  'KcPpssiVDCI',
#  'J7D5RqxlCh4',
#  'QGX-H8sTG8g',
#  'NqDlM6vltjg',
#  'AtLchlrPjos',
#  'hAuUdp94uuE',
#  '3ATrmoZdLsE',
#  '2DfyKCpp5us',
#  'zQ482WjNtIU',
#  'jgbMVYzOQ34',
#  'XqO3zHUaldk',
#  'sEmIOH43jpI',
#  'hbHzdkBn8Lk',
#  'h3s44-3RE2A',
#  'ssJnswvPG1U',
#  '0c7D4jvIEQA',
#  'gONdfOAoTb0',
#  'bALA8aG0S-8',
#  'l_P1HlmqMcg',
#  'aDJrPMTiEts',
#  '1-VJYUsorpk',
#  'vyRSMZIvpkI',
#  'N_2i5fsn0bQ',
#  'BH6UuAD3_XY',
#  'XZrg07Bt0S4',
#  'DrUPIgutX1k',
#  'LwDURWOQEAw',
#  'DTKp56PlgAQ',
#  '_bnjg7cxSgg',
#  'S7em7qEvoT0',
#  'Krdwi0YCFdI',
#  '1YGFZFHZIQ4',
#  'GoFhl-W7VuA',
#  'RYh3a9k3BCY',
#  'QtTE6JiympM',
#  '59loWmMMyVw',
#  '0I5plxuLuZw',
#  'vhR_TJ_qII4',
#  'U3Q10sHKyIA',
#  'YsuLLVH3PWw',
#  '4Vuoqhs5i8M',
#  'URGtDRAu130',
#  'UoW72B0GlIM',
#  'J3Uo1WMytmE',
#  'vROr0Gr5yXM',
#  'o3BSGXWSpEM',
#  'xzFgCynNYR4',
#  'K8ilGJ6s1wc',
#  'rqWCNuSgdL0',
#  'zaCeRJsIsHk',
#  'ZiZKagGi9TE',
#  'o6cSwTdQ-5k',
#  'q-HrAIWXR60',
#  'Ep7VpKGsrYY',
#  'XxyfaxcsMp0',
#  'hiVf_Hzieu0',
#  'iVB0EBFgo08',
#  'mHZTHbzGv68',
#  '030FyhP9dbw',
#  'oYQpgyOggFQ',
#  'OC571n-eJD0',
#  'aXuqDESRu6M',
#  'IlxXcmo0dVM',
#  '9vzu9WdpdN4',
#  'scJ9mYK6Yqs',
#  'tiwLnhx16rs',
#  'VSYWbx2gxEk',
#  '_XLkP_gaaQM',
#  'cFzDdySWd7g',
#  '8qr8Jkkm60g',
#  'oWMwZZ5S3Ms',
#  'KfmFd8f0Icc',
#  'WHtNvcfHmy0',
#  'tBGT35-ESDA',
#  '2H1jmPwbHgg',
#  'vVoxEbQnejY',
#  'IZqqNzn8owo',
#  'JnwWKPRQ4Ss',
#  'S593IC3wNdU',
#  'SbuJq8wfe7I',
#  'EL4x56x32xs',
#  '3DhE5GvyVeo',
#  'YbZcrcobkO8',
#  '_INX5cPEDPE',
#  'YvPyGvxzSHc',
#  'MPN1-pCVuUQ',
#  '7mvUhK5F4co',
#  'T9S2V66K45g',
#  'c8wQ314XIhk',
#  'V15vBcQTHik',
#  'Fwc1jfIAKYk',
#  'JxF-vK62rJk',
#  'D-MjJttaOoo',
#  'g4r_Cv1IaHw',
#  'qsjUcCamMoM',
#  'R1gROoDgPs4',
#  'FIQxam695EU',
#  'OiPGsjT9QKA',
#  'DsQm1kb3ui4',
#  'AfZyyH0KA80',
#  '_rucfHnryyE',
#  'BfZUKrX8OFw',
#  'ISwghahgI24',
#  'RcnDJrDCoeU',
#  'H6hKGmaUPv0',
#  'mAUtJOda1HY',
#  'sRN-6vPXj1U',
#  'vGpUKCSYm4s',
#  'K03JZKa1zXk',
#  'o_T-m7_qVu4',
#  'FBYgBBRny3I',
#  'G0Pu6K7GHEY',
#  'miHXYEtjvf0',
#  'wITCLdPOfqg',
#  'zHFRIWIgqTw',
#  'eW9h81EqpHU',
#  'qBdvoWUrVWM',
#  't-vNKX8LMjA',
#  'orH9vQy9BTQ',
#  'nT2nacrM0hA',
#  '7Y_n4r_J5Zg',
#  '79MoV_vWZzU',
#  'r18N63XtbeE',
#  'rUoYRoS7QUQ',
#  'OsKjTYWFHj4',
#  'LsVd1AQIlDQ',
#  'CvnrL0MwY4g',
#  'V4ECa36lVrE',
#  '9VTYvYkrNKg',
#  '-SpYAqmv228',
#  'xKdf-EJ2iFo',
#  'v-tgm58Tpww',
#  'YbBCNcdlNc4',
#  '4STJmJdFu2Q',
#  '8mX97wMYrhw',
#  'pUxXzHw7g0U',
#  'KFvRKYdp8y8',
#  'qHAbyjH7_Zc',
#  'dvlMFLBITTU',
#  'jQ1_zT2tiqU',
#  'T_Aijvny-4o',
#  'rxVeb1fEz-c',
#  'pWqM-qolpX0',
#  'fB7R10mFGoQ',
#  'ahN426_Uw-g',
#  'kUnKwbTauyQ',
#  'gQS0k0kg3wU',
#  'llrh5zlgbLk',
#  'z2bSqs-ORDI',
#  'TPGEif0F8Z4',
#  'vTxQ_DpTTgM',
#  'KXxRsgM5azY',
#  'xl7PRN1Yhwc',
#  'HnypRPC49nw',
#  'SzYrIGiwX1k',
#  'b0fJwzhLufk',
#  'Bqdke7EyFxw',
#  'NHfIMbB2mtQ',
#  '_JXJtkdsIPA',
#  '-1qzPq3tI-8',
#  'Zm2BEbKgNsk',
#  'w1RewWCmS_Y',
#  'NWchMtixrMU',
#  'maITxdoMI8s',
#  'sDfq7eCQKvI',
#  'O6SPa9foUxY',
#  'j6OYEaeJyoI',
#  'PAeylAQb0sE',
#  '4Khna9hEh8Y',
#  'wktj_amXbXU',
#  'glXZaMJXw7Q',
#  'qkgOVtnBebA',
#  'FGbgA9ZVjLk',
#  'CHvZ2DpwpEU',
#  '8R-gkC-Kd6s',
#  '7qwkVInOPTs',
#  'Uv4tvU69brg',
#  '6YLChD1DVfI',
#  'n6zkBwfU_JU',
#  'lD6XXS2Cvyg',
#  'PPmOxvT92L0',
#  'To72aNKp2X4',
#  '8BTHciR1JK4',
#  'NaJH6ojJ9TE',
#  'wfQJdf_Uq1o',
#  'BEOQxFKzboc',
#  '252rP2RIFYs',
#  'xlFcq65IWnE',
#  'TL8KZe8MU2c',
#  'sO7axRN0uMY',
#  'fG3Xz5PiG6k',
#  'kDzTrJFJLDc',
#  'DxBgQGL7k6I',
#  'hY7Gixxj84Q',
#  'owwdqgB26gk',
#  'DNArjJMeFn4',
#  '_mEvOsvJXSg',
#  'TnG07mXxckQ',
#  'xVGmPeB4HZQ',
#  'Y6azkdQUGa8',
#  'hb1RkHXSe3E',
#  'Cws3Pw0Q-pE',
#  '_RvvdQIJYfc',
#  'TM1VaDE4goc',
#  'p_m93kbqtpE',
#  'iAP57mOxSfc',
#  'A-HCQMWSQLE',
#  'zjaRwcChiI8',
#  'C62wTqPa8CM',
#  'Xx6z40EHXQs',
#  'aDj9HSuVBYM',
#  'NPBPdHZnhjI',
#  'e_DbFw9yB28',
#  'CUdNZoaA6yc',
#  '5H39ejIt-cc',
#  '4FiOgA0HzeQ',
#  'NWIlctMkzIk',
#  '-zqZ1chZUEE',
#  'JL_fSDkmwUQ',
#  '2thsBwZBN0I',
#  'LsSHgsT6AJg',
#  'aHVrQ4NbfUE',
#  'K0_TJmxJsmM',
#  'aTLKgx7h2Lw',
#  '_SD2brw4pzE',
#  'vkSidW8YOsA',
#  'qH0e9nyRiMg',
#  'AbDSqZFDx8g',
#  'cLRWzuFdCVw',
#  'mBjWPK-5k7s',
#  'qceivT1NEAY',
#  'ZWs0yB433WE',
#  'jcbl50K-6Z0',
#  'A_er9nfY110',
#  '3UfkqZVTeyY',
#  'xq1FjiAYJl0',
#  'BfPkQq7Sas8',
#  'f5q3yIPb1-M',
#  '_rvSawmyyNM',
#  'r1MuVc39Xh8',
#  'Wc8W16yAPbU',
#  'M11sklVM5po',
#  'gpFLj3TjqUM',
#  'xMyGR9Bn0HI',
#  'lchRgZ-Q9sY',
#  'VuJMViIHu3M',
#  'xoha9y7QH7s',
#  'kJdYuE42K1c',
#  'peeg_ZmgtTw',
#  '2dPDFcvVZy0',
#  'tbJH3clolCY',
#  '_x1K_CStw1s',
#  'jla7V9uP0F4',
#  'ftO3le8uDgQ',
#  'CATgFeV1V4c',
#  'o24tnbwmzTA',
#  'ngi4JdJjsdA',
#  'X3KEV4MrptE',
#  '9NqkaidS_XY',
#  'E5_hwh7E6q8',
#  'Dbve66dNhwA',
#  'td16kTzD2W8',
#  'DJad_Tz31O4',
#  'm-UPdXRN314',
#  'EponyzAeY7c',
#  '0Jk4l6xfGrM',
#  'WVl6cv2yD9s',
#  '3TXUTguvE4Q',
#  '00Ji0PtcKI8',
#  'VcM40zwD6xQ',
#  'pivkHRNy9d4',
#  'eDYgcOiqlhg',
#  'eUWHoNBer5Q',
#  '30VXB_yMZRg',
#  'vkKmtXNd4v4',
#  '_phRL9VUEzA',
#  'pHJOTf6h6dk',
#  'cKQWI2hoZAc',
#  'RwU54AJX3Io',
#  'cNrsM8HwBKQ',
#  'NzQgTwJ0X-0',
#  '_i9hQ2zYohg',
#  'Y5AaKRlkcaw',
#  'H8EQQujSOsA',
#  'wGN8xwWiXvo',
#  'FPrgRzd4-H0',
#  'vvD5aVHEtX8',
#  '928eE4KyB2A',
#  'uUtE3RlBmzg',
#  'oLPKvgkYH0M',
#  'ztZSJ9F99NE',
#  'J8KNo6ypH6A',
#  'eGldRqvfP0g',
#  'uLGDsHJFlDU',
#  'F8tw0l37x5k',
#  'Gh3KLODoYgE',
#  'vXgqICf_y9I',
#  'Xe4q5BmGalo',
#  'Ceu3s9gaD0I',
#  'm6eud8rGzco',
#  'lPWOkeKN7kA',
#  'mYbAroX-JXQ',
#  'IIjgFfkmaT8',
#  'pWvKFXwmfrk',
#  'F2Q2-xmtgUA',
#  'kvrN9KLbeQ0',
#  '61sb8zpcOTU',
#  'YU2_z0UzvVU',
#  'pv7l2Cxe5ok',
#  'Uj9_C9R9toQ',
#  'JxA_0zecPYA',
#  'RU0Z48QUgDs',
#  'kBCYLKFZme4',
#  'tAQunw2PMi4',
#  'ycN8IE_cgG0',
#  'x54VhIB9EN8',
#  'DcfMTIfP7t0',
#  'fGIFVme6y-U',
#  'DCctZiuspmU',
#  'hw62_NNj3ZY',
#  'Imln_D63RTQ',
#  'AfXaJHaAbT0',
#  'MBF5fr_yOBY',
#  'o0IUZY5wPLY',
#  'YpikBQQpAUY',
#  'oJpFrjwT-MI',
#  'ShS1IH3csnM',
#  '_SMkDYW60mM',
#  'oJLkYHUT-Cg',
#  'whSq_kgMPGg',
#  'NPca1mfMnUc',
#  'wh09kf1-krA',
#  'n7PV_4au3LM',
#  '34qyqoc01xU',
#  '5J5BMif9UBg',
#  'eAD1cOJgFhE',
#  'gFbJXiV6lL0',
#  'fHz_JPBwiIo',
#  '2SgD22GXY_A',
#  'UiI4zYjcqhA',
#  'Zkl3pxtQ--c',
#  'Fq9OtrzBw9U',
#  'cj-9lhidla4',
#  'b8mlh-bARvs',
#  '35rUwebLolM',
#  'Tsq3Wkmkq8E',
#  'o1CNtDedPWw',
#  '2A3QMOV2SeY',
#  'ySzmJf6G4qo',
#  'uzZmvSLj_n0',
#  'N9pZXzzd3tg',
#  'e9d8VZr2neU',
#  '3tbGMt6HFlc',
#  'xSXgyUC82MY',
#  'PAjArUkazHA',
#  'kpYFDgPkbNo',
#  'kVKvTkc3_XA',
#  'coO5fFGhBNk',
#  '4selha9yLgo',
#  'lh2kFiGo-_U',
#  'mORIJySMK_I',
#  'E2cl3fK0gXY',
#  'cmUvffv9SLE',
#  '6U0I-cretEM',
#  'LVa2naEgKLE',
#  'PjeBDUccojo',
#  'c2l9vD-apss',
#  'CV4sKDytwo0',
#  'OTjU22MdvUE',
#  'aXPQnGQ4sZU',
#  '5wfA0z8M0Zk',
#  'Det9DXgXDRE',
#  '57SzDY5slTk',
#  'Kvc-QCcLkro',
#  'UywrXBDrlM4',
#  'LdApqMBtUt8',
#  'rYIxYnWzJ_I',
#  'f2R2HzXT6P4',
#  '06vCWYalK24',
#  'DSiD2WTcvBg',
#  'jNSotOarJ-0',
#  'J9EnPrCZNPQ',
#  'Icj4Fs8uCfQ',
#  'NJ-bbglbOLk',
#  '_xziy85zgp8',
#  'N0gNAp6czAM',
#  'SQrvZ2FVHEs',
#  'Q-okkA_iDbU',
#  'vilFuOUQ1fQ',
#  'armdaYTowoA',
#  'jfv7hIQQNyU',
#  'JwXwUR8HTz8',
#  'RHpOu4co5W0',
#  'medHTraY19o',
#  '2jqpeqs50EQ',
#  '7x8Qs90JMDg',
#  'Ldyp1PZOcS4',
#  'Fj3pukXNNdk',
#  'sxAgVs08v-U',
#  'grgKLwRWXPA',
#  'PMJAiIiGMvk',
#  '63zRSTkb8Qc',
#  'lVzLONulMoc',
#  'b3gHC5WU7rg',
#  '-tdj3Zb-jvg',
#  'uZ4x32DvYOs',
#  'TqxKHk07p5A',
#  'BNvvI5F-JFM',
#  '_34qWM-J-Ho',
#  'kTWs8a-MXWQ',
#  'yl43pmh6lAE',
#  'KrIqjq10B6s',
#  '0K_RlqRxnls',
#  'wRfkwFu1coM',
#  'Haz9BCyE5_0',
#  'G5mbyiJ96ak',
#  'G9d2b76wtsw',
#  'lCmXWOjw1QQ',
#  'AF-w1cEFUhA',
#  '0dCynSFTVR0',
#  'O_ssXqBm8J0',
#  'GeL-Bk2Gyrg',
#  'GZtrErBg2_k',
#  'RWZ-DSWDl5w',
#  'GrjwtXeXEUg',
#  'ZR7oNuD2Bwg',
#  'K75kJ09QkxI',
#  'd_gq85s14Rk',
#  'yCudV212ohI',
#  'zi8pmY0BwFE',
#  'nQv1D1mHVt8',
#  'B8deFW4z-xk',
#  'hB6Q6yIeuGQ',
#  'N5D73_MF1XA',
#  'VItTrUOaGKs',
#  '8Ip9BmGVmRw',
#  'VdWzSZDuN6g',
#  'EUqj638oySg',
#  'ertHRKolH4I',
#  'DsG4xZpqznc',
#  'JYfkx6SidRs',
#  'HdYnHUtXZu4',
#  'jKAColf24XY',
#  'IcwuZEkThCs',
#  'ycBHsYIsd4E',
#  'y6-MKIhqsj0',
#  'wR-P8fdwguo',
#  'XAofRbqxwBw',
#  'otePKZkKlxQ',
#  'C-OHlNvGUEw',
#  'xkUfB-itlMw',
#  'dqYh1DUNlgA',
#  '1EYuiWkGMXg',
#  'DBfx6VgLSVQ',
#  '9sBgseTrj1Q',
#  '5F6oDMnZAS8',
#  'z2b0l-2t1gg',
#  '5g7CtZoo5GU',
#  'oUGea_dz4Hc',
#  'dP-cS89nHr4',
#  'kFCy24AU7Bc',
#  '0Xcd7NSFBBM',
#  'OA68xEjzonM',
#  '1lUYZ38pE_s',
#  'nM6Se_EIQbo',
#  'aVADCiIpdnc',
#  '_ELKyeVNW7A',
#  'ODQpEZ5nZVI',
#  '6AO54rb1MwI',
#  'kcXEY3_w2EA',
#  'spQvEjl270w',
#  'LS1hyN53WEg',
#  'BrKbvYR1WP8',
#  'zo2JRSfwCT4',
#  'iCocZyxLYzk',
#  'mx5K0ERLPAE',
#  'GYvAxJGnGOc',
#  'pSppf8efJf4',
#  '6RE8wpwtEcQ',
#  'JUPFWB4k-Eo',
#  'LpdKUbPs8Yg',
#  'lVUhTQFUG14',
#  'Hq7gpV5JWC0',
#  'pIzFQMtrdMI',
#  'oUaIX4uKfPE',
#  '0hRQC9E68bo',
#  'qPDD_yLWUbU',
#  'p8L1W4w8GzU',
#  '4ST5aNUJBYs',
#  '8zFE0e3XmSY',
#  'mt_pNEgux44',
#  'bbBpnV984OU',
#  'x0-SXnXSjJw',
#  'sqYugFma4-A',
#  'NyV9jGa_HSE',
#  'jOSdmRWXHD0',
#  '1oMG7G58Jnw',
#  'T2Vr0ldNBqg',
#  '6eu6FAnOZbM',
#  'ACI_jNzKZCc',
#  '1cRJGFKsj6M',
#  'SBro07KZC0o',
#  'dcvdPgqB_yw',
#  'gGPAjWkDQ54',
#  'dKZiNE4CaIA',
#  'ktpyDomFF0k',
#  'n1WncZguKRQ',
#  'YhSq0PbAgZM',
#  'bckHEDGR9qg',
#  '9mUm2TFGLfI',
#  'uEIVAeleaN8',
#  'JPwrp8I5N2c',
#  'jx-JPEj1tG4',
#  'uZSxKcXyssM',
#  'FE8r8_sJms4',
#  'iJQaF5PN_0M',
#  'knjrPkWXSik',
#  'fx1pY4qOga8',
#  'n4ZsX5RFfWs',
#  '3bU0StMbMqE',
#  'AWJRlfxcq7M',
#  'dwue770pyfQ',
#  'aBqZhNOs4O8',
#  'dhryEGid0jo',
#  'E-MucVpJodo',
#  '6F9zZ_Widp4',
#  'MbICypw711g',
#  'rlqpwTObQuE',
#  'NS8Gus5XEk0',
#  'cYXbjsIsNNo',
#  'jYgkvHIkvN8',
#  'Gy_hiPvBvEY',
#  '49pPBzu7tBc',
#  'fG_z1-0UVSg',
#  'OhsajCzOyGQ',
#  'ebzE3f9ByT8',
#  '6asIaxMHqOA',
#  'gMDmngMPXXo',
#  '-LhVmJIZCl0',
#  'rNh16Nq1mlg',
#  'lK5214fV3IE',
#  'AmNOnsBzjYw',
#  'I7RSbgRlixc',
#  'X_d9TiOJa0w',
#  'bvd1Ba6HbwY',
#  'n6Za66zMvyA',
#  '6qO7IUrhWHw',
#  'gh1Etl_TjeM',
#  'JO6BVOpp0PA',
#  'UA6AOGRh3n4',
#  'yY2-Su1rWeU',
#  'GQo8AWE_TgM',
#  'mtuwriwbK9U',
#  'kz7VZNBWM68',
#  'VxtPhDY9om0',
#  'OBPe0xzaL20',
#  'ISW0n8VMaZg',
#  'UtV07E_Yynk',
#  'HfCY02mT-TU',
#  'XtMkYVpX3R0',
#  'ioCBzpVyor8',
#  'uah6sPmfYEA',
#  'lPaECjmv9VA',
#  'f6QsgAmTdIY',
#  'efd3Y6sC97c',
#  'NagFZNf1_TY',
#  'wsNIWZF_yRs',
#  'RjKg7uGeMs4',
#  'gXvTItAZRug',
#  'm6pwyqxqZxs',
#  'zNMT_IV6XBk',
#  'yXrSVcl5Vl0',
#  'KYfEEHN_IDk',
#  'J2uO_vpMjvE',
#  'HopBgmT2a8M',
#  '4hKJoxbjFBA',
#  'eW_0EaKTq6E',
#  'ZvvknIbYmgc',
#  'EodHKf5FGvQ',
#  'KLjmeUANIS8',
#  '6C3FBgm1TPo',
#  'SSQ05g6VOTw',
#  '_6ZdYQInHB4',
#  'LuVz9vg4F88',
#  '3ZewkeS9f0Q',
#  'x8uaXCPL1gI',
#  'JNrJz7yLo1o',
#  '8uDpGLsoPE4',
#  'pKNBPkKprw4',
#  'JPglPUv_WKI',
#  'NvXhJkSAE0w',
#  'i4-nB6wacVI',
#  'vpkDMmZ_wN0',
#  'UTMHExrFMiw',
#  'KgdLyA5978U',
#  'ct9VddcCg5Y',
#  'zC_otaB_-cw',
#  'aiWdCEaAzYY',
#  'GiWTaCMILAk',
#  'VuMTo2E9FhQ',
#  'wTMlnIjxOnY',
#  'W7jBdDsDoOE',
#  'HIEsb9xTXkg',
#  'Jen9XnbaywM',
#  'Gi3JlTXvV1w',
#  'FUnny_ucc3c',
#  'nh1BdWMp9Qk',
#  '4aE5cYR2XVE',
#  'G5mAbQ6_4qY',
#  '_BBjJn_FB5I',
#  'e8wOZDLB_FM',
#  'KNdtun0w_AM',
#  'i1Jpl1PCprY',
#  'OBk-e3WZE6I',
#  'TL1l1J-gtgY',
#  'gXq0OwKFcSs',
#  '9EGeEX2KQDI',
#  'hVBLWPxw1_c',
#  '7RcdEY24pXQ',
#  'm_EijJL10j4',
#  'aiCFrB6cAio',
#  'qeQW5TJCytU',
#  'eMZKzQpjeu4',
#  'HZtcqMFOmCY',
#  'GLUcPJhG4c4',
#  '8s3k_0pvvMk',
#  'MuJhV-6zR8k',
#  'sgD3X2gVP1A',
#  '0nnxrR5dmio',
#  'F30pb26qx6Q',
#  '6rYdOYEKoe4',
#  'yEfi9WMTb_E',
#  'YZ5Evrb0DAc',
#  'vH2Ra_9rhC0',
#  'Z-aemXg_t00',
#  '_23HFoWrwM8',
#  'RIJR_nnVvEM',
#  'E52PGrLJqkM',
#  '0FFyjCaiLJs',
#  'y5B7V4Pd6mc',
#  'd_rPqzNt38g',
#  'zzCeYnus5_o',
#  '7__DWFQXwsw',
#  '0Abdw_RLoU4',
#  'A8kRSSMWe-w',
#  'QdtAPZUnh4E',
#  'ZmGNBSUwXyc',
#  'NuZY-3J6W5c',
#  'NXxbui-kqzA',
#  'bn_lQAP8td0',
#  'sE5lPpwlOmU',
#  'C8K-eIZ1Ahc',
#  'FmtR2qFtIsQ',
#  '7OEMQLp9Vxg',
#  'QHipMF8fJ5I',
#  'iQ66QoSlZVg',
#  'XY__DVwdmSQ',
#  'RHurZFPciTI',
#  'cJjLoOXGu2g',
#  '6brXRJW3GGE',
#  'ut7UgnxTvr4',
#  'z_OZwUfsQCE',
#  'hodO0_KYq4A',
#  'aqHQj27bkOk',
#  'VF3QYtwR21A',
#  'sBqUKfi4ng4',
#  'qDKbvB-Ikfs',
#  'NAxvQrjQizE',
#  'dVc2yLg68i0',
#  'GI2UvkgXDOI',
#  'llGpprWm_Nw',
#  'DnQYqJ_5PyU',
#  '6L0b8VdkBn4',
#  '0HjJd-C9Q1o',
#  'CrE5WtUAoBU',
#  '8BO94EG3-ds',
#  'rasEHAMqjPI',
#  'g9DzAjIcyfo',
#  'MOyYqJ0jjF0',
#  'K1TapZ0h89A',
#  'k5LqOT1ODPo',
#  'Y4THbj-oktc',
#  'oFfQAQKGV7w',
#  'j0HXAg5ytUU',
#  '8epz9cas7os',
#  'ycugqP3Skmk',
#  'DPZ4hBFxg24',
#  'k9cBK8MaD1g',
#  'Q-TH9pRidlM',
#  'yfa-7jg3SIc',
#  'Ea4-v54tRuA',
#  'hgd16QPp5Bo',
#  'iAXz27gFtvo',
#  'O_DmHd9MlCw',
#  'dx46C_2fg9U',
#  'uK7WSPqWh_U',
#  '2StTCEZzlO8',
#  'hDXTRqj0XHI',
#  'kuAjXYQFqTA',
#  ...]

# %%
#video details 
def get_video_info(video_ids):
    video_data=[]   
    for video_id in video_ids:
        request=youtube.videos().list(
           part = 'snippet,ContentDetails,statistics',
           id=video_id
        )
        
        response=request.execute()
        for items in response ['items']:
            data =dict(Channel_Name= items ['snippet']['channelTitle'],
                   Channel_Id =items ['snippet']['channelId'],
                   Video_id = items['id'],
                   Title= items['snippet']['title'],
                   Tags= items.get('tags'),
                   Thumbnail= items['snippet']['thumbnails'],
                   Descripition=items.get('description'),
                   Published_Dates= items['snippet']['publishedAt'],
                   Duration= items['contentDetails']['duration'],
                   Views= items.get('viewCount'),
                   comments= items.get('commentCount'),
                   Favorite_Count=items['statistics']['favoriteCount'],
                   Definition= items['contentDetails']['definition'],
                   Caption_status=items['contentDetails']['caption'],
                   )
            video_data.append( data )
        return video_data

# %%
video_info=get_video_info(Video_Ids)

# %%
video_info
# Out:
# [{'Channel_Name': 'Chennai Super Kings',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'gnDsz6Wspk4',
#   'Title': '"Grateful for the six-years" - The Journey of Rutu - Lions up close',
#   'Tags': None,
#   'Thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/gnDsz6Wspk4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/gnDsz6Wspk4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/gnDsz6Wspk4/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/gnDsz6Wspk4/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/gnDsz6Wspk4/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'Descripition': None,
#   'Published_Dates': '2024-04-02T13:54:19Z',
#   'Duration': 'PT4M51S',
#   'Views': None,
#   'comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'}]

# %%
#command details
def get_comment_info(video_ids):
    Comment_data=[]

    try:
        for video_id in video_ids:
            request=youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=50
            )
            response=request.execute()

            for item in response['items']:
                data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                        video_Id =item['snippet']['topLevelComment']['snippet']['videoId'],
                        Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                        Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
                Comment_data.append(data)
            
    except:
        pass
    return Comment_data

# %%
comment_details=get_comment_info(Video_Ids)

# %%
comment_details
# Out:
# [{'Comment_Id': 'Ugz54j0bL-B5F9xwmed4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Ruturaj 🔥',
#   'Comment_Author': '@Starboy182k',
#   'Comment_Published': '2024-04-03T08:27:17Z'},
#  {'Comment_Id': 'UgyfK-6T8QBkU9EEwEB4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Ms dhoni fan 💛💛💛💛💛💛',
#   'Comment_Author': '@basudevbesra834',
#   'Comment_Published': '2024-04-03T06:55:12Z'},
#  {'Comment_Id': 'Ugy8xMz8e3GN2CN18DV4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'KKR Became More Dangerous With Guru Gambhir Mentorship',
#   'Comment_Author': '@ExpertFreeTips',
#   'Comment_Published': '2024-04-03T06:19:29Z'},
#  {'Comment_Id': 'Ugx0a09-aJxMnjToQdN4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Is it true that ms is out of ipl!!',
#   'Comment_Author': '@niharranjanchakravarty2432',
#   'Comment_Published': '2024-04-03T05:52:01Z'},
#  {'Comment_Id': 'Ugy7P2-KmKURCY7Q9rl4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Respect bottom',
#   'Comment_Author': '@AhmadKhan-pv9uo',
#   'Comment_Published': '2024-04-03T04:53:50Z'},
#  {'Comment_Id': 'UgyQwaAnEOk6r62OVbB4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'He didn&#39;t use OBVIOUSLY 😮😂',
#   'Comment_Author': '@jahnavij1405',
#   'Comment_Published': '2024-04-03T04:47:35Z'},
#  {'Comment_Id': 'UgxZQWrNIMbUmD_95JF4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Rutu come back stronger ..dont be under pressure due to ur captaincy we know ur a good player we need that old rutu again we want to see ur flying sixes ....❤ come back soon ❤',
#   'Comment_Author': '@manimaranveerasamy2722',
#   'Comment_Published': '2024-04-03T04:45:10Z'},
#  {'Comment_Id': 'UgwFmdb9hWt1eqA6uEF4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Ruturaj yarr run kab banaaoge , Mitchell se run nhi ban rhe , dube fast bowlers nhi khel paa rha hai , jaddu se finishing nhi ho rhi , rachin off side ki ball pe struggle kar rha hai , rahane ka bharosa nhi , rizvi ka bhi bharosa nhi , chahar powerplay me run peeta rha hai mujhe nhi lagta ki iss bar hum log 6th trophy jeetenge😢😢😢😢',
#   'Comment_Author': '@Shivansh-mishraa',
#   'Comment_Published': '2024-04-03T03:56:18Z'},
#  {'Comment_Id': 'Ugzy0wFB3SDfXtcJJA14AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Dhoni 💛💛💛💛💛💛💛💛💛💛💛💛💛',
#   'Comment_Author': '@ashok_mudhiraj_2125',
#   'Comment_Published': '2024-04-03T03:51:22Z'},
#  {'Comment_Id': 'UgzSFc8O169M7EfrcI94AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Mama inu inta rutu thirunthala mama please correct ur weakness of left arms bowlers',
#   'Comment_Author': '@user-jb1iz2vy1z',
#   'Comment_Published': '2024-04-02T19:14:35Z'},
#  {'Comment_Id': 'UgzXWUErrUOJQ7RRAfJ4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Comeback 💛',
#   'Comment_Author': '@kushagrasingh698',
#   'Comment_Published': '2024-04-02T18:25:55Z'},
#  {'Comment_Id': 'Ugxmj4gVvnrx-vVXE194AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Please buy Mayank Yadav at auction',
#   'Comment_Author': '@mohammedsuhayl9190',
#   'Comment_Published': '2024-04-02T18:19:55Z'},
#  {'Comment_Id': 'UgyQYMJX-8W5_v_nV6t4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Bro work on strike rate your strike rate and Kohli strike rate are same ❤❤',
#   'Comment_Author': '@DhruvKumbhkar',
#   'Comment_Published': '2024-04-02T18:12:14Z'},
#  {'Comment_Id': 'Ugw7-jmTNt7HwicW6654AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Definitely, Always with you Captain. Keep moving ahead !! I trust you.',
#   'Comment_Author': '@actoromchoudhary',
#   'Comment_Published': '2024-04-02T17:49:12Z'},
#  {'Comment_Id': 'UgzqFaO1eGbMPK1h-854AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Just waiting excitedly to see the rocket take offf 🚀🎉🚀',
#   'Comment_Author': '@danceofficial2219',
#   'Comment_Published': '2024-04-02T17:48:18Z'},
#  {'Comment_Id': 'UgwOtE1dzEilZbBoFOJ4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Csk 💛 💛',
#   'Comment_Author': '@abdulyt748',
#   'Comment_Published': '2024-04-02T17:42:23Z'},
#  {'Comment_Id': 'UgwL_Qpg0FElDZIEtRR4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': '💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛',
#   'Comment_Author': '@MrShyamKumar-tt5xh',
#   'Comment_Published': '2024-04-02T17:22:51Z'},
#  {'Comment_Id': 'UgwOKMIaJh8WLlQTyAd4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'CSK win the final 2024🏆🏆🏆🏆🏆🏆',
#   'Comment_Author': '@kanhabarik3536',
#   'Comment_Published': '2024-04-02T17:12:08Z'},
#  {'Comment_Id': 'UgzePOPGkwJU58Iw4IJ4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'The next match of <a href="http://www.youtube.com/results?search_query=%23csk">#CSK</a> will be won by whistle podu 🤞💛🏆',
#   'Comment_Author': '@manohar_kushwaha058',
#   'Comment_Published': '2024-04-02T16:52:21Z'},
#  {'Comment_Id': 'UgyRJ878TJUYcllVcEV4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': '💛💛💛💛CSK💛💛💛💛rutu forever ♾️',
#   'Comment_Author': '@leenaleena2221',
#   'Comment_Published': '2024-04-02T16:30:23Z'},
#  {'Comment_Id': 'Ugyyd48Eq2sosxmIx0t4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'ruturaj score century vs srh',
#   'Comment_Author': '@vinayakgupta5097',
#   'Comment_Published': '2024-04-02T16:13:34Z'},
#  {'Comment_Id': 'UgzlWmXNYUbHVH3Uue94AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Come back CSK in 4th match',
#   'Comment_Author': '@mvsdeepakguptadeepakgupta567',
#   'Comment_Published': '2024-04-02T16:09:52Z'},
#  {'Comment_Id': 'UgxTNer2HHsA1E5did14AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Captain waste 😂 1 run out agiduvan😅😅',
#   'Comment_Author': '@jananisankar6509',
#   'Comment_Published': '2024-04-02T16:05:06Z'},
#  {'Comment_Id': 'UgzZbeR70eo5GHXYqqx4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': '❤❤❤😌😌😌😍😍😍😘😘😘',
#   'Comment_Author': '@smratsharma5724',
#   'Comment_Published': '2024-04-02T16:02:32Z'},
#  {'Comment_Id': 'Ugyni7YVLVkXw-EYNXR4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Rutu Don&#39;t take up the captaincy pressure I want u to focus on ur batting after ipl u have T20 world cup I want u to be in that squad be consistent in ur batting U have more competition 💛💛💛',
#   'Comment_Author': '@sbqueen5741',
#   'Comment_Published': '2024-04-02T15:57:07Z'},
#  {'Comment_Id': 'UgwuHGjwWfh5NrfWhxx4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'M: MASTER MIND<br>S:SUPER SPEED<br>D:DANGEROUS<br>H:HARDWORK<br>O:OSCURWINNING PERSON<br>N:NEVER GET ANGRY<br>I:INDIAN BEST CAPTAIN<br><a href="http://www.youtube.com/results?search_query=%23thala">#THALA</a> FOR A REASON💛💛💛💛',
#   'Comment_Author': '@KNIGHTGAMING-106',
#   'Comment_Published': '2024-04-02T15:56:26Z'},
#  {'Comment_Id': 'UgyVQpgArbqpUL9dB6Z4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'M . S . D . H . O . N . I = 7 LETTERS <br>THALA FOR A REASON 💛💛💛',
#   'Comment_Author': '@KNIGHTGAMING-106',
#   'Comment_Published': '2024-04-02T15:56:20Z'},
#  {'Comment_Id': 'UgwGFaSz8nqUf56bnS94AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'IF I TRICK YOU YOU WILL GIVE HEART TO ME PLZ <br><br><br>READ MORE',
#   'Comment_Author': '@KNIGHTGAMING-106',
#   'Comment_Published': '2024-04-02T15:55:02Z'},
#  {'Comment_Id': 'UgxtpCJWAaj2y7qkfJ94AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'next match win the game',
#   'Comment_Author': '@kunalkushwah2754',
#   'Comment_Published': '2024-04-02T15:54:53Z'},
#  {'Comment_Id': 'Ugx-pXO5yk7jUrnQK0h4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'As csk followers kindly improve your skills against left arm fast bowler .',
#   'Comment_Author': '@vidhyasagarn5642',
#   'Comment_Published': '2024-04-02T15:42:24Z'},
#  {'Comment_Id': 'UgzXO_cRlDGLk0Bph2l4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'U can champ comeback stronger 💛💛💛',
#   'Comment_Author': '@jenix8717',
#   'Comment_Published': '2024-04-02T15:41:35Z'},
#  {'Comment_Id': 'UgzGdkeaV6U1sxmiObF4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'I just didn&#39;t realise that rutu is a senior now',
#   'Comment_Author': '@clashingyard7792',
#   'Comment_Published': '2024-04-02T15:39:21Z'},
#  {'Comment_Id': 'Ugy04ICGAGrqZaTJDk14AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Love you bro',
#   'Comment_Author': '@clashingyard7792',
#   'Comment_Published': '2024-04-02T15:36:23Z'},
#  {'Comment_Id': 'Ugy_8-bE-NGxUEqm4Wt4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Admin, please said to rutu we want a great innings from him',
#   'Comment_Author': '@praveenkumardantham4585',
#   'Comment_Published': '2024-04-02T15:21:08Z'},
#  {'Comment_Id': 'UgyI_YyNRaqFqLn9SI14AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'We are waiting for rutu century ❤🎉',
#   'Comment_Author': '@user-gr6hb9cd2w',
#   'Comment_Published': '2024-04-02T15:20:07Z'},
#  {'Comment_Id': 'Ugwq3I8AjPVhF6ewzhV4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'CSK fail what 😢',
#   'Comment_Author': '@kalidoss857',
#   'Comment_Published': '2024-04-02T15:19:18Z'},
#  {'Comment_Id': 'Ugzai2mJon3jrH85GxN4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': '💛💛💛💛💛💛💛💛💛💛',
#   'Comment_Author': '@vijeyakumarniluksi1874',
#   'Comment_Published': '2024-04-02T15:11:01Z'},
#  {'Comment_Id': 'UgwldKYNdGqNnokYYmF4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Dhoni forever like<br>👇',
#   'Comment_Author': '@srinivasankothandaraman5480',
#   'Comment_Published': '2024-04-02T15:09:08Z'},
#  {'Comment_Id': 'Ugy4_h3Q1H9oW5WKYhZ4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': '❤❤❤❤❤',
#   'Comment_Author': '@143_BTS_dil',
#   'Comment_Published': '2024-04-02T15:07:29Z'},
#  {'Comment_Id': 'UgzzJ-NOxx2RFNT9zXt4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Next match is with srh<br>The defeat will surely tell where we went wrong<br>This would be helpful against srh as they have more beast batters<br><a href="http://www.youtube.com/results?search_query=%23believeinyellove">#Believeinyellove</a>💛',
#   'Comment_Author': '@sufiyanshikalgar8145',
#   'Comment_Published': '2024-04-02T15:02:43Z'},
#  {'Comment_Id': 'UgxxaPePqLsTCOdzE_d4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Any Marathi CSK fan here 💛💛',
#   'Comment_Author': '@user-yh2dv4pi3i',
#   'Comment_Published': '2024-04-02T14:33:27Z'},
#  {'Comment_Id': 'UgyM3LVFzUrpEB_A1C54AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Ruturaj and our thala are emotions❤❤💛💛💛💛💛💛💛💛💛💛',
#   'Comment_Author': '@v2gameryt667',
#   'Comment_Published': '2024-04-02T14:33:05Z'},
#  {'Comment_Id': 'Ugx4prgSR2IkwKMsNUZ4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Hoping for the bug knocked slipper 😊',
#   'Comment_Author': '@DanishKhan-41104',
#   'Comment_Published': '2024-04-02T14:29:08Z'},
#  {'Comment_Id': 'UgzaCM1v4R4et1hQEdh4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': '&quot;This is just the start of many things to come&quot; 🤌🧿❤️\u200d🔥',
#   'Comment_Author': '@Rutika7',
#   'Comment_Published': '2024-04-02T14:28:06Z'},
#  {'Comment_Id': 'UgzT7gicRkdSRs_c-Ah4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Good that we lose early so we can fix things ✨❤️\u200d🔥❤️\u200d🔥',
#   'Comment_Author': '@DanishKhan-41104',
#   'Comment_Published': '2024-04-02T14:26:36Z'},
#  {'Comment_Id': 'Ugy__l0HgpAJAPtwitN4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Good to see old training kit jersey returning. Rutu looking really good in that :)',
#   'Comment_Author': '@bhargavram4027',
#   'Comment_Published': '2024-04-02T14:26:19Z'},
#  {'Comment_Id': 'Ugyl3FtfPh7ArvewH9N4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Ruturaj Gaikwad century is coming',
#   'Comment_Author': '@crizzlyroom',
#   'Comment_Published': '2024-04-02T14:25:37Z'},
#  {'Comment_Id': 'UgwI652ycMg2mROlrxB4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'Jai CSK MSD my heartbeat 💛💛💛',
#   'Comment_Author': '@ravigorle1284',
#   'Comment_Published': '2024-04-02T14:24:19Z'},
#  {'Comment_Id': 'UgxvurMyJ74og1dSStJ4AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': '<a href="http://www.youtube.com/results?search_query=%23yellove">#yellove</a>❤️❤️',
#   'Comment_Author': '@snehal_07',
#   'Comment_Published': '2024-04-02T14:20:48Z'},
#  {'Comment_Id': 'Ugx_d3i3Jb8XcyqeHp54AaABAg',
#   'video_Id': 'gnDsz6Wspk4',
#   'Comment_Text': 'LION STARTED THE ROAR🦁🦁🦁',
#   'Comment_Author': '@DattasaiMummadisetti',
#   'Comment_Published': '2024-04-02T14:17:27Z'},
#  {'Comment_Id': 'UgzfZQfOX-fMpUlEAoZ4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Thala wins our hearts',
#   'Comment_Author': '@Aman_world_wide',
#   'Comment_Published': '2024-04-03T06:14:49Z'},
#  {'Comment_Id': 'UgzXblbsUyYUR5YZIP14AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'We want csk to win upcoming matches ❤',
#   'Comment_Author': '@charu563',
#   'Comment_Published': '2024-04-03T04:42:48Z'},
#  {'Comment_Id': 'Ugw8N1M2tSxNvBHzx9h4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': '❤❤❤❤❤❤❤❤❤❤',
#   'Comment_Author': '@ashok_mudhiraj_2125',
#   'Comment_Published': '2024-04-03T03:50:49Z'},
#  {'Comment_Id': 'Ugwp3GOba7dVsn4tJi94AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Meanwhile hitman duck 🔥🙌',
#   'Comment_Author': '@vigneshmohan1464',
#   'Comment_Published': '2024-04-03T03:36:25Z'},
#  {'Comment_Id': 'UgzfeNvdIwpExPyQit14AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'thala plz finish 1 match in your style .<br>msd love you',
#   'Comment_Author': '@Quickcric07',
#   'Comment_Published': '2024-04-03T02:02:24Z'},
#  {'Comment_Id': 'UgxC0Tvh55IVGKZTozh4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Why no mention of Ajinkya Rahane’s fighting 45? Why does your channel always ignore his wonders on the field?',
#   'Comment_Author': '@bp5970',
#   'Comment_Published': '2024-04-02T20:13:33Z'},
#  {'Comment_Id': 'Ugw4TaX7zANDg0XDUBB4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'फिनिशर का राजा mahi bhai❤',
#   'Comment_Author': '@video_Channel3',
#   'Comment_Published': '2024-04-02T19:08:29Z'},
#  {'Comment_Id': 'UgxJN7rdnoLoFgRW5at4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Love you Mahi❤',
#   'Comment_Author': '@AksharaRadhika',
#   'Comment_Published': '2024-04-02T18:22:40Z'},
#  {'Comment_Id': 'UgxJ4U9k6Np0ffmADqR4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'When some matches are played,  we feel dejected if our team loses. But the match between CSK and DC brought a smile to all CSK fans even when we lost, in fact to all who saw the match. That&#39;s because of Mahi ❤.  Take a bow, Mahi🌹Sheer entertainment and goosebumps. CSK team 💛 all the best to u.',
#   'Comment_Author': '@ac3361',
#   'Comment_Published': '2024-04-02T17:56:32Z'},
#  {'Comment_Id': 'UgzzRbm5b3Aw3SIqA7B4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'CSK win final 2024🏆🏆🏆🏆🏆🏆',
#   'Comment_Author': '@kanhabarik3536',
#   'Comment_Published': '2024-04-02T17:12:58Z'},
#  {'Comment_Id': 'UgxXYoCd9__FJ3tZCBB4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Mukesh starck',
#   'Comment_Author': '@nccnoormohammed',
#   'Comment_Published': '2024-04-02T16:46:59Z'},
#  {'Comment_Id': 'UgzmgP7Fz67AFohW2yR4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Thala Turned Back The Clock For That 30 Minutes💪',
#   'Comment_Author': '@k8pooool',
#   'Comment_Published': '2024-04-02T16:20:29Z'},
#  {'Comment_Id': 'Ugx8aNaeTEGHNgLY7Y94AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Being a CSK fan since my childhood I felt bad for a moment that it lose against DC .But literally had no regret of lose bcz Indian saw their Thala for the first time of this ipl season,what can be the happiness after that.<br>Lots of respect and love MSD sir.......<br>U has created a big space in the heart of all cricket lover across the world including myself.',
#   'Comment_Author': '@mohammadirfan6091',
#   'Comment_Published': '2024-04-02T16:19:33Z'},
#  {'Comment_Id': 'UgzN6jVYGhDzSDlCEAl4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Love from vizag <a href="http://www.youtube.com/results?search_query=%23csk">#csk</a> <a href="http://www.youtube.com/results?search_query=%23msd">#msd</a>',
#   'Comment_Author': '@DeeepThink',
#   'Comment_Published': '2024-04-02T15:46:17Z'},
#  {'Comment_Id': 'UgyFyXb1jfgnWOqf7IZ4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Dhoni sir❤❤❤❤',
#   'Comment_Author': '@kns3053',
#   'Comment_Published': '2024-04-02T15:09:14Z'},
#  {'Comment_Id': 'UgyMgftDomZTDsp0VqV4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'we want tribute for doug Bollinger..🖐️🖐️',
#   'Comment_Author': '@user-gq1cg6xm6r',
#   'Comment_Published': '2024-04-02T15:00:09Z'},
#  {'Comment_Id': 'UgwhMMz4EgP1DKhOpt54AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Thala💛',
#   'Comment_Author': '@-justwatch145',
#   'Comment_Published': '2024-04-02T14:31:00Z'},
#  {'Comment_Id': 'UgxXN6RQjB08CtwWLQ54AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Mahi ❤❤',
#   'Comment_Author': '@official__mr_mahi7788',
#   'Comment_Published': '2024-04-02T13:48:21Z'},
#  {'Comment_Id': 'UgyTcC34Pipu9qzmc7R4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': '❤❤❤❤❤❤❤',
#   'Comment_Author': '@shitalmeshram220',
#   'Comment_Published': '2024-04-02T13:37:56Z'},
#  {'Comment_Id': 'UgwYPV1WTgtqB3H96S54AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Use spin. That is our template rutu. Pls bring moen ali in place of Mitchell',
#   'Comment_Author': '@mohanapriyaasaithambi8322',
#   'Comment_Published': '2024-04-02T13:26:51Z'},
#  {'Comment_Id': 'UgxTnV7zd8ZAC8QCBU54AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Infinity love for mahi and csk🇮🇳🦁💛🛐♾️🤩🥰😘👌🏻🫶🏻💪🏻❤️💯',
#   'Comment_Author': '@manideepreddy9766',
#   'Comment_Published': '2024-04-02T13:20:21Z'},
#  {'Comment_Id': 'UgwO_cTIrNffws6MOqF4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Thala😍',
#   'Comment_Author': '@dhonisivanthi',
#   'Comment_Published': '2024-04-02T13:18:10Z'},
#  {'Comment_Id': 'UgykuGvfFA_CFNOoPUN4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Thala doni💛💛💛💛',
#   'Comment_Author': '@Kanapathymadhushan',
#   'Comment_Published': '2024-04-02T12:58:21Z'},
#  {'Comment_Id': 'Ugy6WtTCIf6YglAo6bp4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Love mahi bhai',
#   'Comment_Author': '@Dharmendra23896',
#   'Comment_Published': '2024-04-02T12:31:43Z'},
#  {'Comment_Id': 'UgyAKDar_n_IfmtbH-t4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': '😊❤',
#   'Comment_Author': '@saritaparashar1962',
#   'Comment_Published': '2024-04-02T12:22:45Z'},
#  {'Comment_Id': 'Ugw7slSkYSmvtwnwnxl4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Dear Msd boys pls like 200 likes 😊❤',
#   'Comment_Author': '@chandruvj274',
#   'Comment_Published': '2024-04-02T11:54:24Z'},
#  {'Comment_Id': 'Ugx4JwILOZ1-MdDGd8d4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': '❤🎉❤🎉Mahi our jaan❤🎉❤ Mahi is legend ❤🎉Mahi our love 💕 Mahi our Happiness ❤🎉❤Mahi our Emotions ❤🎉❤ MAHI Sirf Mahi,Thala,MSD, nahi hain woh  hamare &quot;ATTITUDE&quot; Hain.❤🎉❤ Love MAHI sir❤🎉❤ GOD BLESS YOU...',
#   'Comment_Author': '@worldadventure5558',
#   'Comment_Published': '2024-04-02T11:47:26Z'},
#  {'Comment_Id': 'UgyOixpWwLnBR4MVz8t4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Mahi❤🎉❤',
#   'Comment_Author': '@worldadventure5558',
#   'Comment_Published': '2024-04-02T11:42:55Z'},
#  {'Comment_Id': 'UgydzoTWaBfoeqrUwEt4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'MSD and csk team ❤',
#   'Comment_Author': '@SekharchCh-yi2tn',
#   'Comment_Published': '2024-04-02T11:33:06Z'},
#  {'Comment_Id': 'UgzOjpEodSveemWVx9B4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Rk voice after long time😊',
#   'Comment_Author': '@N.Praewin',
#   'Comment_Published': '2024-04-02T11:29:40Z'},
#  {'Comment_Id': 'UgwL88yx_D_hNMFCejV4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Doesn&#39;t matter which team wins,I am here for entertainment.<br>                    ~MS Dhoni🔥',
#   'Comment_Author': '@AniksWorld23',
#   'Comment_Published': '2024-04-02T11:27:32Z'},
#  {'Comment_Id': 'UgyDGo_AE62Z2yzLY-t4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': '💛Ruturaj gaikwad (2021) की आत्मा 💓Riyan parag (2024) में घुस गई हैं 😂 रितुराज गायकवाड़ कुछ कर यार कहां गया वो foam 🏏',
#   'Comment_Author': '@chessglance2725',
#   'Comment_Published': '2024-04-02T11:19:28Z'},
#  {'Comment_Id': 'UgyV3NFG7HNBuBdxKsB4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Want thala century',
#   'Comment_Author': '@AdityaSabat7781',
#   'Comment_Published': '2024-04-02T10:59:13Z'},
#  {'Comment_Id': 'Ugx0wZuNAVBnr9Fiw094AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Lion started the roar',
#   'Comment_Author': '@DattasaiMummadisetti',
#   'Comment_Published': '2024-04-02T10:56:29Z'},
#  {'Comment_Id': 'UgxOZIBhflymVXm6f154AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': '❤❤🎉🎉💛💛💪🇧🇩',
#   'Comment_Author': '@sojib..9999',
#   'Comment_Published': '2024-04-02T10:49:00Z'},
#  {'Comment_Id': 'UgzkL5m21_0Bb3TKeXt4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Longevity of Thala = Infinity. <br>I am not sure if Thala  belongs to this planet.<br>Respect 💯',
#   'Comment_Author': '@mubarakhussain7560',
#   'Comment_Published': '2024-04-02T10:45:39Z'},
#  {'Comment_Id': 'UgzqDsRu4m-3S71C4yl4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Mahi on a wheel chair and he still would win matches for you.',
#   'Comment_Author': '@mubarakhussain7560',
#   'Comment_Published': '2024-04-02T10:44:41Z'},
#  {'Comment_Id': 'Ugw_f2sdOClVNUNK6Bx4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': '&quot;Mahii abhi bhi maar raha hai&quot;. The same way he scored his first ODI century against Pakistan in this very ground.',
#   'Comment_Author': '@mubarakhussain7560',
#   'Comment_Published': '2024-04-02T10:42:52Z'},
#  {'Comment_Id': 'UgyGJpMfTHSABlzdqR94AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': '😊😊😊',
#   'Comment_Author': '@ShankarPoudel-vo1pw',
#   'Comment_Published': '2024-04-02T10:37:41Z'},
#  {'Comment_Id': 'UgzgUdMD-qt_DYg-Ty54AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Thala Forever 🥺',
#   'Comment_Author': '@Leo_Das_Csk_7',
#   'Comment_Published': '2024-04-02T10:31:09Z'},
#  {'Comment_Id': 'Ugyj7JHfxOCvV7MISUh4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Good to hear back RK voice 😌✌🏼',
#   'Comment_Author': '@Dummybawa007-ys9ck',
#   'Comment_Published': '2024-04-02T10:30:19Z'},
#  {'Comment_Id': 'UgwQLb5rgkbickugcW54AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': '❤❤❤',
#   'Comment_Author': '@NiteshYadav-cp2lo',
#   'Comment_Published': '2024-04-02T10:29:59Z'},
#  {'Comment_Id': 'UgwPIhfGN3hCgoTCRx54AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Msd',
#   'Comment_Author': '@user-kh1de9ou9v',
#   'Comment_Published': '2024-04-02T10:29:27Z'},
#  {'Comment_Id': 'Ugzs4O22ahI6cwV_qXR4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Thala 💛💛💛',
#   'Comment_Author': '@user-qp7ro1cy2g',
#   'Comment_Published': '2024-04-02T10:28:59Z'},
#  {'Comment_Id': 'UgzVvjn6sTYWf9ajT2h4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Mahi bhai ke bale ke aage koi bol skta h kya💛💛💛💛💛💛💛💛',
#   'Comment_Author': '@Goyalansh7',
#   'Comment_Published': '2024-04-02T10:28:57Z'},
#  {'Comment_Id': 'Ugz9ljIRox6J4FmgfIB4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Matheesha pathirana is the best in death over for CSK 🏆🏆🏆🏆🏆',
#   'Comment_Author': '@manohar_kushwaha058',
#   'Comment_Published': '2024-04-02T10:28:52Z'},
#  {'Comment_Id': 'Ugw3YkvYw63HG_MlA3B4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'respect button for MSD',
#   'Comment_Author': '@balagaming2822',
#   'Comment_Published': '2024-04-02T10:25:08Z'},
#  {'Comment_Id': 'UgyqAJI_1uN-UvKhkPl4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'NXT match we want Mukesh choudhary..😢',
#   'Comment_Author': '@ajith_official8927',
#   'Comment_Published': '2024-04-02T10:21:51Z'},
#  {'Comment_Id': 'UgyIr3ChhBg17YbFegJ4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'Dhoni fans 🥰 assembly here<br>👇',
#   'Comment_Author': '@rishikeshRaj-hh5tf',
#   'Comment_Published': '2024-04-02T10:18:27Z'},
#  {'Comment_Id': 'Ugz3sqPlYkkcg5aL4Ox4AaABAg',
#   'video_Id': 'b7NnlZuexd0',
#   'Comment_Text': 'We for MS Dhoni💝💝💝💝💝💝💝',
#   'Comment_Author': '@user-jk7wu6nm4j',
#   'Comment_Published': '2024-04-02T10:17:44Z'},
#  {'Comment_Id': 'UgyzDr3N4L59EhJ1YOR4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'Fully vadakku players, ithu chennai super kings illa vaddakku super kings',
#   'Comment_Author': '@mohammedunishj406',
#   'Comment_Published': '2024-04-03T06:49:38Z'},
#  {'Comment_Id': 'UgwN18ceOINOu0I3OTJ4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'RUTURAJ GAIKWAD 💛🪄',
#   'Comment_Author': '@sheejasheeja2806',
#   'Comment_Published': '2024-04-03T05:41:41Z'},
#  {'Comment_Id': 'Ugz6p4n81ME6mtldw0l4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'These youngsters ❤',
#   'Comment_Author': '@Dontsubscribe10000',
#   'Comment_Published': '2024-04-03T04:25:07Z'},
#  {'Comment_Id': 'UgzBMeXwZUEuKlDLmSl4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': '❤❤❤❤❤❤❤❤❤❤',
#   'Comment_Author': '@Kettevan',
#   'Comment_Published': '2024-04-03T03:50:05Z'},
#  {'Comment_Id': 'UgwcvwOe-sCsrLt9Kl54AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'Come on CSK win 🏆 the upcoming matches Prove the opponent Teams wrong come back stronger THALA Dhoni7 your are a finisher forever 💛🦁🏆🏏☄️🔥🔥🔥',
#   'Comment_Author': '@HA-wd6jx',
#   'Comment_Published': '2024-04-02T16:11:39Z'},
#  {'Comment_Id': 'UgwaNktBqrlc8XzRx5t4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'My family : Chitra, Suresh, Krisesh.<br>Take the first letter of each name.<br>CSK is formed.<br>CSK = Chitra Suresh Krisesh in Chennai cheering for Super Kings.',
#   'Comment_Author': '@KriseshVinay',
#   'Comment_Published': '2024-04-02T14:55:57Z'},
#  {'Comment_Id': 'UgyiVdxRI7dnt3zHvfJ4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': '7 is the greatest all the time 🔥🔥💛',
#   'Comment_Author': '@karnamrohith14',
#   'Comment_Published': '2024-04-02T12:08:50Z'},
#  {'Comment_Id': 'Ugy5HROV55igGqkfICt4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': '81💛💛💛💛',
#   'Comment_Author': '@Cricketlover99611',
#   'Comment_Published': '2024-04-02T11:57:49Z'},
#  {'Comment_Id': 'UgxhjNkXI-voHrsDrrl4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'Dhoni ka baap Virat Kohli 💪💪',
#   'Comment_Author': '@user-sh2db7yx7j',
#   'Comment_Published': '2024-04-02T11:49:01Z'},
#  {'Comment_Id': 'Ugw0bz5TvLoxqGkZsl94AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'PLS GIVE 10 TO SHARDUL HE DESERVE IT',
#   'Comment_Author': '@kunalsingh10.4',
#   'Comment_Published': '2024-04-02T10:26:02Z'},
#  {'Comment_Id': 'UgxPM00AUg77s9x4rXF4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'MS Dhoni binds and carries CSK team like  &quot; Hum 7-7 hai&quot; .',
#   'Comment_Author': '@mubarakhussain7560',
#   'Comment_Published': '2024-04-02T09:49:43Z'},
#  {'Comment_Id': 'UgytNzpB9rF8swqPfC54AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'thala dhoni...💛💛💛<br>whistle podu...💛💛💛<br>thala dhoni fans like here...💛💛💛<br>👇',
#   'Comment_Author': '@user-su9ty9rl1n',
#   'Comment_Published': '2024-04-02T09:49:29Z'},
#  {'Comment_Id': 'UgwfrY64hXPD18RqOU14AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'No. 7- MSD. <br>This number needs no introduction or explanation.',
#   'Comment_Author': '@mubarakhussain7560',
#   'Comment_Published': '2024-04-02T09:43:55Z'},
#  {'Comment_Id': 'Ugz_kNMsfcR1kBpZ8-54AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': '❤❤❤❤',
#   'Comment_Author': '@ashok_mudhiraj_2125',
#   'Comment_Published': '2024-04-02T09:37:40Z'},
#  {'Comment_Id': 'UgwhFTzl7up4wi7dFkh4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'Ask 7😊',
#   'Comment_Author': '@Theflimcreator',
#   'Comment_Published': '2024-04-02T09:03:39Z'},
#  {'Comment_Id': 'Ugx0eRIKQXk4Eaku8Pp4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'DHONI🥰 fan assembly here<br>👇',
#   'Comment_Author': '@rishikeshRaj-hh5tf',
#   'Comment_Published': '2024-04-02T08:36:29Z'},
#  {'Comment_Id': 'Ugz6LgfeHf5JhvUXpXJ4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'Pls pin third',
#   'Comment_Author': '@srinivasankothandaraman5480',
#   'Comment_Published': '2024-04-02T08:28:12Z'},
#  {'Comment_Id': 'UgwCTq6HR2uuJnkwzpR4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'number should be unique for everyone. and that should be strictly followed.. every player should be known by their own number. they should work hard for it and create meaning for that particular number and make people to remember them by their number.',
#   'Comment_Author': '@keepsmiling83',
#   'Comment_Published': '2024-04-02T08:28:01Z'},
#  {'Comment_Id': 'UgwpxnTZohO12FxF9Zx4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'Do more of these!',
#   'Comment_Author': '@ashishmks__06',
#   'Comment_Published': '2024-04-02T08:19:44Z'},
#  {'Comment_Id': 'UgymAXwCzY4mhjHxbXd4AaABAg',
#   'video_Id': 'pGFjLV1C2Z4',
#   'Comment_Text': 'Chennai ipl status please',
#   'Comment_Author': '@ishitasirse1016',
#   'Comment_Published': '2024-04-02T08:08:04Z'},
#  {'Comment_Id': 'UgxHwpO4XqVBcq6Fuxd4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': '😢😢😢😢❤❤❤❤❤❤❤❤',
#   'Comment_Author': '@Yusuf-ge8hc',
#   'Comment_Published': '2024-04-03T08:38:48Z'},
#  {'Comment_Id': 'UgxKro9s5kCJ0QbIw_h4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'His father was Graound men.. ❤️❤️♥️',
#   'Comment_Author': '@narenoraon232',
#   'Comment_Published': '2024-04-03T08:06:25Z'},
#  {'Comment_Id': 'UgzBEskXsr5k2rbOCGt4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Ms dhoni big fan 😎😎😎',
#   'Comment_Author': '@AyushmaanMishra-un8du',
#   'Comment_Published': '2024-04-03T08:00:01Z'},
#  {'Comment_Id': 'UgzWKH7EVnRwDFsPtN54AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Thala msd🔥❤🔥🔥',
#   'Comment_Author': '@sreelethajayan3971',
#   'Comment_Published': '2024-04-03T07:11:19Z'},
#  {'Comment_Id': 'Ugyrr6eJpZxBV4D05Qt4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Dhoni sir ka 148 runs wali innings se he maine dhoni sir ko dekha wahi se dhoni sir ka match dekta aa rahu abhi tak uskay pahle k 4 innings mai dekha bhi nhi tha inka us din se he mai cricket ko dekha ❤❤',
#   'Comment_Author': '@RohanGupta-kr7rx',
#   'Comment_Published': '2024-04-03T06:41:57Z'},
#  {'Comment_Id': 'UgzhnVbcP87POB3URjR4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'The man, The math, The lagend, the emotion, forever 💛💛💛💛💛💛😢😢😢',
#   'Comment_Author': '@suklasingh4259',
#   'Comment_Published': '2024-04-03T05:02:02Z'},
#  {'Comment_Id': 'UgzN6ZeNslT2LbH4LSB4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Mahi Bhai always wins our heart 💓',
#   'Comment_Author': '@barmanrohan',
#   'Comment_Published': '2024-04-03T04:38:00Z'},
#  {'Comment_Id': 'UgyIJykOBmMxv_jB7cB4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Kash mein bhi staff member hota 😭😭<br>LOVE YOU THALA 💛💛',
#   'Comment_Author': '@reyansh3',
#   'Comment_Published': '2024-04-03T03:57:38Z'},
#  {'Comment_Id': 'Ugyz0W-i0gq-P-YBTYl4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Thala...name for a reason.❤',
#   'Comment_Author': '@prabakarviswanathan927',
#   'Comment_Published': '2024-04-03T03:40:02Z'},
#  {'Comment_Id': 'UgxI66LUVGgvawTq2K54AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': '❤❤❤❤',
#   'Comment_Author': '@jannsaraah5060',
#   'Comment_Published': '2024-04-03T03:25:29Z'},
#  {'Comment_Id': 'UgzO8U7F1SueU7rERgZ4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Whatever MSD does, is loveable !!',
#   'Comment_Author': '@NarayananMurthyblogs',
#   'Comment_Published': '2024-04-03T03:24:45Z'},
#  {'Comment_Id': 'UgzEje1GOT7jKUsaSTF4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Real bahubali of India',
#   'Comment_Author': '@ahasazanaz944',
#   'Comment_Published': '2024-04-03T03:17:06Z'},
#  {'Comment_Id': 'UgxW4-SJxKnxTNmWRNd4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Virat kohli jai shree virat kohli',
#   'Comment_Author': '@SaritaDevi-ye1zz',
#   'Comment_Published': '2024-04-03T01:31:58Z'},
#  {'Comment_Id': 'UgyIdiBjXNYg3Rf9sux4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'It&#39;s remind me of that day when he finally Say good bye to cricket.',
#   'Comment_Author': '@ami.middle-classengineer8020',
#   'Comment_Published': '2024-04-02T20:59:46Z'},
#  {'Comment_Id': 'Ugzl4eJ3D3HPUsTdkHd4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Our Thala is a pure talent and humble person. I pray that he stays healthy and fit. His darshan from the dressing room is more than enough for us. We can&#39;t see him suffering with 1 leg hopping. Thank You Mahi 💛💛💛💛💛💛💛.',
#   'Comment_Author': '@tamildharma',
#   'Comment_Published': '2024-04-02T20:22:17Z'},
#  {'Comment_Id': 'UgydXQNtGnhBb0L95hx4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'फिनिशर का राजा mahi bhai❤',
#   'Comment_Author': '@video_Channel3',
#   'Comment_Published': '2024-04-02T18:46:12Z'},
#  {'Comment_Id': 'UgwqULoCYmPOGavdA9Z4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Thanadakam',
#   'Comment_Author': '@user-wq3lw2dg2n',
#   'Comment_Published': '2024-04-02T18:27:59Z'},
#  {'Comment_Id': 'UgzxTlUCFNZSv4yrWnx4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Ms Dhoni forever 💛💛💛💛',
#   'Comment_Author': '@sherbahadursingh2157',
#   'Comment_Published': '2024-04-02T17:51:16Z'},
#  {'Comment_Id': 'Ugwzamrv0f1UKIcorVN4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'The man the myth the legend 💛🛐🦁',
#   'Comment_Author': '@Tanishq.1758',
#   'Comment_Published': '2024-04-02T17:34:31Z'},
#  {'Comment_Id': 'UgyzLMG_yr99HDeDB-F4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': '<a href="http://www.youtube.com/results?search_query=%23yellove">#yellove</a>❤️❤️',
#   'Comment_Author': '@snehal_07',
#   'Comment_Published': '2024-04-02T16:44:58Z'},
#  {'Comment_Id': 'Ugy0W2PqXelKdJvrGI94AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'What&#39;s problem msd in leg 😢',
#   'Comment_Author': '@garudagamingyt1460',
#   'Comment_Published': '2024-04-02T16:43:50Z'},
#  {'Comment_Id': 'UgwDeXspxlcLSBhgMAp4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'MSD❤❤❤',
#   'Comment_Author': '@samitasajeevan2659',
#   'Comment_Published': '2024-04-02T16:42:31Z'},
#  {'Comment_Id': 'UgzeDOi9mshAwTw22oB4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'If You Don&#39;t like Thala will not play <br>👇',
#   'Comment_Author': '@scpedits1233',
#   'Comment_Published': '2024-04-02T16:14:13Z'},
#  {'Comment_Id': 'Ugzt8WyDz6FRYNZbynB4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'It is hard to imagine cricket without dhoni after his retirement<br>Forever ♾️♾️ Dhoni.......',
#   'Comment_Author': '@user-dp5wp3ue6w',
#   'Comment_Published': '2024-04-02T15:19:14Z'},
#  {'Comment_Id': 'Ugx61jpvTh5scvWXVK94AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'All see thala &#39;s smile<br>But no one see his pain',
#   'Comment_Author': '@sakirsameja8629',
#   'Comment_Published': '2024-04-02T15:16:57Z'},
#  {'Comment_Id': 'Ugw3qgxJHaq5lvyNXWp4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'CSK❤❤❤❤',
#   'Comment_Author': '@nilimagangurde-khairnar5386',
#   'Comment_Published': '2024-04-02T14:50:29Z'},
#  {'Comment_Id': 'Ugzt3Fyx6aQ1cwNgi1x4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Mahi💛💛',
#   'Comment_Author': '@-justwatch145',
#   'Comment_Published': '2024-04-02T14:33:07Z'},
#  {'Comment_Id': 'UgzMjRCA2F9-kuP1nGV4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': '♥️♥️',
#   'Comment_Author': '@shreyashukla6172',
#   'Comment_Published': '2024-04-02T13:02:48Z'},
#  {'Comment_Id': 'UgxQJELYcKFKuG1yb7t4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': '💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛csk',
#   'Comment_Author': '@prakashdetake5953',
#   'Comment_Published': '2024-04-02T11:57:26Z'},
#  {'Comment_Id': 'Ugw9v-AOqWpd4nMIk4Z4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Reason for thala 💛💛💛💛💛💛💛💛',
#   'Comment_Author': '@user-nv5ou4ji7h',
#   'Comment_Published': '2024-04-02T11:56:30Z'},
#  {'Comment_Id': 'UgzNpfI92HgApJO5w154AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': '❤❤❤❤❤❤❤❤',
#   'Comment_Author': '@user-ec4si9cq1t',
#   'Comment_Published': '2024-04-02T11:43:32Z'},
#  {'Comment_Id': 'UgwmGHQ4dhWBoG2UmhN4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Super  captain cool',
#   'Comment_Author': '@user-ee1ts8cw7z',
#   'Comment_Published': '2024-04-02T11:43:04Z'},
#  {'Comment_Id': 'UgxQ45PZ-Vg1KyuaP4h4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': '😍😍😍😍',
#   'Comment_Author': '@bharat5506',
#   'Comment_Published': '2024-04-02T11:42:02Z'},
#  {'Comment_Id': 'UgxkPAQFs3yXfbfvhDh4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Anybody notice left leg injury 😢 I am proud to say always I am dhoni fan💛💛💛🔥👑',
#   'Comment_Author': '@abkdimentionworld',
#   'Comment_Published': '2024-04-02T11:10:05Z'},
#  {'Comment_Id': 'UgxJxeCrLTBB25j6UCR4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Ms teling telugu కూర్చో ♥️♥️🥰🥰😍😍',
#   'Comment_Author': '@guruvolgos1943',
#   'Comment_Published': '2024-04-02T11:08:07Z'},
#  {'Comment_Id': 'UgxLk6_XZp-xo0tBZ694AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'My dream to meet him❤️',
#   'Comment_Author': '@killerbean6938',
#   'Comment_Published': '2024-04-02T11:00:46Z'},
#  {'Comment_Id': 'UgxBASUle5fCP3OalyR4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Forever boss',
#   'Comment_Author': '@dboss7691',
#   'Comment_Published': '2024-04-02T10:59:37Z'},
#  {'Comment_Id': 'UgwkyYVinOOACPt79WN4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'What happened to thala leg 😢',
#   'Comment_Author': '@cricketlovers1698',
#   'Comment_Published': '2024-04-02T09:55:57Z'},
#  {'Comment_Id': 'UgyMRH1YRAprGIqyTOZ4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'The legend mahi bhai ❤❤',
#   'Comment_Author': '@rewatkhedkar5095',
#   'Comment_Published': '2024-04-02T09:52:01Z'},
#  {'Comment_Id': 'Ugw7elyiXHR3k-KHJS54AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Thala da',
#   'Comment_Author': '@itsmenila1435',
#   'Comment_Published': '2024-04-02T09:12:30Z'},
#  {'Comment_Id': 'Ugxi5OFm-MllHjfl18J4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': '🙋🙋🙋🙋🏆🙋🙋🙋🏆🏆🏆🏆🏆',
#   'Comment_Author': '@SaviSingh-by1lb',
#   'Comment_Published': '2024-04-02T09:08:56Z'},
#  {'Comment_Id': 'UgyeOlxaj9fKwgI3zxB4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Ms dhoni ke per me abhi bi injri he',
#   'Comment_Author': '@rahulnamdev803',
#   'Comment_Published': '2024-04-02T09:08:05Z'},
#  {'Comment_Id': 'Ugzn3_LMNAlfpHjfleR4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'It&#39;s pure love❤ isn&#39;t it?.....just look at their faces.<br>This man gets nothing but they? They have gotten themselves a memory of their life..<br>Thala for a reason ❤',
#   'Comment_Author': '@thribhuvan8982',
#   'Comment_Published': '2024-04-02T09:02:32Z'},
#  {'Comment_Id': 'UgwAArQJwUB3NhOOb0J4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'आप चले गये तो मैं आयपीएल देखना छोड',
#   'Comment_Author': '@roopatamrakar3208',
#   'Comment_Published': '2024-04-02T08:52:01Z'},
#  {'Comment_Id': 'UgyyU3-DhrA7QZMsb0V4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'भैया प्लीज मत जाना माई भाई प्लीज मत जाना आयपीएल के किंग',
#   'Comment_Author': '@roopatamrakar3208',
#   'Comment_Published': '2024-04-02T08:51:34Z'},
#  {'Comment_Id': 'Ugy-gcvj7OI8f-I-CuN4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'our  thalaaaaaaa💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛',
#   'Comment_Author': '@petsworld5129',
#   'Comment_Published': '2024-04-02T07:53:37Z'},
#  {'Comment_Id': 'UgzCFeIRcwOkPkT0lSp4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'It hurts see Mahi like this🥺💔',
#   'Comment_Author': '@abhishek2001',
#   'Comment_Published': '2024-04-02T06:59:06Z'},
#  {'Comment_Id': 'UgyN9YzeXoRHsEu_tDV4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Full lucky 😅',
#   'Comment_Author': '@puspalatasahoo-5362',
#   'Comment_Published': '2024-04-02T06:53:03Z'},
#  {'Comment_Id': 'UgzVUDky_8B4whQ1XK14AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Thala is our emotion',
#   'Comment_Author': '@URBAN806',
#   'Comment_Published': '2024-04-02T06:34:13Z'},
#  {'Comment_Id': 'UgwQazs5XPUMdYep7aB4AaABAg',
#   'video_Id': 'XGH-EOgVP-4',
#   'Comment_Text': 'Thala for a reason 💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛💛',
#   'Comment_Author': '@user-ds5jb1nb4d',
#   'Comment_Published': '2024-04-02T06:26:58Z'},
#  {'Comment_Id': 'UgzIp1eyzsCJDj2dlcB4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'Love u mahi vhi',
#   'Comment_Author': '@sadstatuszone175',
#   'Comment_Published': '2024-04-03T08:04:46Z'},
#  {'Comment_Id': 'UgzqlK11K4sIkheR6MV4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'L7. 7 u u y',
#   'Comment_Author': '@DineshYadav-xk1vp',
#   'Comment_Published': '2024-04-03T08:03:35Z'},
#  {'Comment_Id': 'Ugy3KeuthN2QUuvaB0l4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'One word 🙏🙏 legend 🥰🥰🥰🥰🙏🙏🇨🇦',
#   'Comment_Author': '@prabathanga7107',
#   'Comment_Published': '2024-04-03T07:20:38Z'},
#  {'Comment_Id': 'UgymvJc85vUP_TsJEEl4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'The Man, The Myth , The Legend 🔥<br>One &amp; Only<br>Mahendhra Singh Dhoni 💛',
#   'Comment_Author': '@sreeraghsree1432',
#   'Comment_Published': '2024-04-03T07:15:51Z'},
#  {'Comment_Id': 'UgwNA3jngArPbYxeRDZ4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': '💛💛💛💛',
#   'Comment_Author': '@mr_bikram9151',
#   'Comment_Published': '2024-04-03T06:28:40Z'},
#  {'Comment_Id': 'UgxTEXxP8bkaafofT-x4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'Love this man',
#   'Comment_Author': '@jioadarshpatel5544',
#   'Comment_Published': '2024-04-03T05:25:40Z'},
#  {'Comment_Id': 'UgwEDatHobtWk6s1ARp4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'फिनिशर का राजा Mahi Bhai 🔥❤️',
#   'Comment_Author': '@video_Channel3',
#   'Comment_Published': '2024-04-03T04:41:02Z'},
#  {'Comment_Id': 'UgyZcDiYDh3zLhO81od4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'Dhoni ❤️❤️❤️',
#   'Comment_Author': '@prasantpal8047',
#   'Comment_Published': '2024-04-03T04:38:23Z'},
#  {'Comment_Id': 'UgyX0vnhsrULBFubkzp4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'Not only csk all cricket fans assembled here',
#   'Comment_Author': '@user-qr9lt4me9x',
#   'Comment_Published': '2024-04-03T04:36:31Z'},
#  {'Comment_Id': 'UgxhyM-mF3Oscdj92Fp4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'Bas dhoni sir💛🇮🇳',
#   'Comment_Author': '@gulshanhrxdhoni3621',
#   'Comment_Published': '2024-04-03T01:50:03Z'},
#  {'Comment_Id': 'Ugxeyig25_U_QVVI3994AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'MSD carrier started from Vizag 1st century, after a long time again he played good shots and best innings in Vizag.  our Vizag is always special and sentiment for movies too, 100&#39;s of movies shot here that have been super hits. I wish Dhoni would play another 1 year more if his body support him. we love you dhoni from Vizag.',
#   'Comment_Author': '@dinneshpedada1903',
#   'Comment_Published': '2024-04-02T22:15:59Z'},
#  {'Comment_Id': 'UgznjCAql3AomSio01R4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'G O D',
#   'Comment_Author': '@playerunknownspartan8321',
#   'Comment_Published': '2024-04-02T18:45:13Z'},
#  {'Comment_Id': 'UgwYP8dDkvlfOsUPGmd4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'MSD❤❤❤',
#   'Comment_Author': '@sakshi7670',
#   'Comment_Published': '2024-04-02T18:05:46Z'},
#  {'Comment_Id': 'UgwqxpWjUwqpJSiFcbx4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'DC  won the match  but  MSD winning the  Hearts 💖.',
#   'Comment_Author': '@IffatKarimaRaita-oc6hx',
#   'Comment_Published': '2024-04-02T15:20:08Z'},
#  {'Comment_Id': 'Ugy0ueNSF4bIo_h5UK14AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'MSD is not a man.. not at all a group.. Its a religion with universal laws.. Proud to be MSDian.. Great honour to me..',
#   'Comment_Author': '@Kingsiva87',
#   'Comment_Published': '2024-04-02T14:38:26Z'},
#  {'Comment_Id': 'UgwghSalyc42XofKY8V4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'Waste',
#   'Comment_Author': '@shivakarthik.m3512',
#   'Comment_Published': '2024-04-02T13:54:08Z'},
#  {'Comment_Id': 'UgySFJDe8Kn0sNv98t94AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'What happened when he came',
#   'Comment_Author': '@shivakarthik.m3512',
#   'Comment_Published': '2024-04-02T13:53:45Z'},
#  {'Comment_Id': 'UgyaFJU9oV09yElpu8l4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'Enna projno',
#   'Comment_Author': '@shivakarthik.m3512',
#   'Comment_Published': '2024-04-02T13:53:24Z'},
#  {'Comment_Id': 'Ugz3VobBxt0bqwIR8sJ4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'தோல்வியிலும் துவண்டு போகாத ஒரே தலைவன்',
#   'Comment_Author': '@VaibzTV',
#   'Comment_Published': '2024-04-02T13:35:51Z'},
#  {'Comment_Id': 'UgzAUthPaEh4so2p73p4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'no one can ever come close to the great MS Dhoni legacy',
#   'Comment_Author': '@SagarKumar-li4um',
#   'Comment_Published': '2024-04-02T13:31:59Z'},
#  {'Comment_Id': 'UgzIQg1gqwJ49W5aalZ4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'He is legend',
#   'Comment_Author': '@gobindarabha1018',
#   'Comment_Published': '2024-04-02T13:04:56Z'},
#  {'Comment_Id': 'Ugwf9ty650H1WabQprF4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'TATA IPL❌<br>THALA IPL✅',
#   'Comment_Author': '@MyLove_SARADA',
#   'Comment_Published': '2024-04-02T13:01:40Z'},
#  {'Comment_Id': 'UgztpY81FGl1GvD7k454AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'Imagine the youngsters playing in the opposite team. Its a great moment to catch up with MSD post match. These are priceless moments for them which they will cherish for life..',
#   'Comment_Author': '@saivigneshastrocare',
#   'Comment_Published': '2024-04-02T12:07:21Z'},
#  {'Comment_Id': 'UgwjQ9TE3WM2ePEzjwd4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'Msd❤❤',
#   'Comment_Author': '@yashdesai814',
#   'Comment_Published': '2024-04-02T11:58:06Z'},
#  {'Comment_Id': 'Ugy9qiZ8KTQrlizBuFB4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'Soooo happyy to see <a href="http://www.youtube.com/results?search_query=%23thala">#Thala</a> back in his finishing style.. None were sad of losing this time.. All that matters is his performance and smile.. 🧿💛✨',
#   'Comment_Author': '@jahanviajaykumar4247',
#   'Comment_Published': '2024-04-02T11:51:08Z'},
#  {'Comment_Id': 'UgxVANwHEvHJwl5sblZ4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'MSD 💛',
#   'Comment_Author': '@officialm1705',
#   'Comment_Published': '2024-04-02T10:59:44Z'},
#  {'Comment_Id': 'UgwByqUNCya6eUs43594AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'When Mahi stops playing cricket, I will stop watching cricket.',
#   'Comment_Author': '@MrGoyari007',
#   'Comment_Published': '2024-04-02T10:04:28Z'},
#  {'Comment_Id': 'UgzWus1W_kjQx2WrHWV4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': '❤',
#   'Comment_Author': '@albinbabu347',
#   'Comment_Published': '2024-04-02T09:59:59Z'},
#  {'Comment_Id': 'UgyaI13He-ceUE7lbXN4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'Har Generation mein ek ya do player ko brand BCCI banta hain Sunil Gavaskar, Kapil Dev, Sachin, Yuvraj, Dhoni, Virat, Rohit ab Virat jaatein jaatein apni legacy ya BCCI ka Brand hain woh kisi aur Player ko deke jayega, BCCI ko Shubman Gill Next Gen Indian cricket team ka brand banana hain, Brand Player banega tabhi Cricket Next Gen mein aagey jaayega &amp; Paisa banega.',
#   'Comment_Author': '@sachinedit5209',
#   'Comment_Published': '2024-04-02T09:58:17Z'},
#  {'Comment_Id': 'Ugz8NtHDEccDFC7-o794AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'THE MAN<br>THE MYTH<br>THE LEGEND<br>MSD ❤🦁.',
#   'Comment_Author': '@MahakalBhakt-rw5mk',
#   'Comment_Published': '2024-04-02T09:51:01Z'},
#  {'Comment_Id': 'UgxiICzW0oYYRwUriT94AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'After my family it&#39;s dhoni',
#   'Comment_Author': '@abhilashkondru2730',
#   'Comment_Published': '2024-04-02T09:19:44Z'},
#  {'Comment_Id': 'UgyC3wHQfhAcOTxYDwl4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
#   'Comment_Text': 'Yellow army here💛',
#   'Comment_Author': '@rajeshchoudhary2900',
#   'Comment_Published': '2024-04-02T09:17:13Z'},
#  {'Comment_Id': 'UgzB5fsd2cwU9Yr-sNl4AaABAg',
#   'video_Id': 'HFQ3bmji_ns',
# ...
#  {'Comment_Id': 'UgxSm3npE_uXLtPxZlB4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Rachin❤ baba',
#   'Comment_Author': '@Chris2flye',
#   'Comment_Published': '2024-03-27T09:20:30Z'},
#  {'Comment_Id': 'UgwligPA4Uf--fN_srR4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Saw Match In Stadium I Caught CSK Fever 💛😢',
#   'Comment_Author': '@Chethu1229',
#   'Comment_Published': '2024-03-27T08:46:55Z'},
#  {'Comment_Id': 'Ugz0eaeIiFAvo5tJydx4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Hu',
#   'Comment_Author': '@user-ir7vw2xl1h',
#   'Comment_Published': '2024-03-27T08:35:11Z'},
#  {'Comment_Id': 'Ugydbe6WN325SJZtsWt4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Fizz is coming🥶🥶',
#   'Comment_Author': '@zarifsvlogs8070',
#   'Comment_Published': '2024-03-27T08:22:45Z'},
#  {'Comment_Id': 'UgyKmdvT-AbrLHG9BqB4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'माय ऑल टाइम फेवरेट टीम वन एंड ऑनली सीएसके 🥰🥰🥰🥰🥰🥰💕💕💕💕💕💕💕💕💕',
#   'Comment_Author': '@SudhirKumar-dv6wr',
#   'Comment_Published': '2024-03-27T07:58:24Z'},
#  {'Comment_Id': 'UgxR9Gs9zuZYibx7WCx4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Mukesh Coudhary &gt;&gt; Tushar Deshpandey',
#   'Comment_Author': '@k_a3276',
#   'Comment_Published': '2024-03-27T07:14:11Z'},
#  {'Comment_Id': 'Ugw-B26I7MCQzwgHWet4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': '😮',
#   'Comment_Author': '@kshitijsingh1375',
#   'Comment_Published': '2024-03-27T07:12:13Z'},
#  {'Comment_Id': 'UgxiitR6JZNnWfP-gZl4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Csk thaka op ❤',
#   'Comment_Author': '@agrimguglani2293',
#   'Comment_Published': '2024-03-27T05:57:35Z'},
#  {'Comment_Id': 'UgwrPmNfHkmXCM3egA94AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'thala forever...',
#   'Comment_Author': '@user-su9ty9rl1n',
#   'Comment_Published': '2024-03-27T05:10:57Z'},
#  {'Comment_Id': 'UgzS5Z9ngNqU2P3B1d14AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Thala Dhoni',
#   'Comment_Author': '@jayantakumarghosh-mc4rl',
#   'Comment_Published': '2024-03-27T05:01:10Z'},
#  {'Comment_Id': 'UgxJ3N3zWaEX2l4vlMN4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Guys, this CSK squad is something else! We got explosive opening pair, strong middle order batsman,lower order batsman like Rizvi hit some big sixes in. <br>We got powerplay specialist fast bowler like D.Chahar,Death over specialist like Fizz and Pathirana <br>Jadeja ,santenar, thekshana, moeen Ali on the spinning side!<br>We got <a href="http://mr.cool/">Mr.cool</a> Ms dhoni with his student and our new captain Rutu<br>Dhois experience is giving us goods in every match.<br>Who will stop this CSK?',
#   'Comment_Author': '@shubhamshinde9265',
#   'Comment_Published': '2024-03-27T04:03:18Z'},
#  {'Comment_Id': 'UgwmYuORzDvGBsdNIKN4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'matheesha pathirana',
#   'Comment_Author': '@Mathi-creation-2023',
#   'Comment_Published': '2024-03-27T03:44:10Z'},
#  {'Comment_Id': 'Ugx3kXbVeufesPadLNR4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': '🏆🥇🥇🥇🏆 My ⭐⭐⭐ players',
#   'Comment_Author': '@freeFire-tr3lv',
#   'Comment_Published': '2024-03-27T03:11:28Z'},
#  {'Comment_Id': 'UgxFLStwa1VeHVlxB-d4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Mahi the legend💛💛💛💛💛💛💛💛',
#   'Comment_Author': '@venumgaming8533',
#   'Comment_Published': '2024-03-27T02:52:29Z'},
#  {'Comment_Id': 'UgxJa1QugUHrP5I0XDp4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Mahi mara hai ❤❤❤❤',
#   'Comment_Author': '@kdharamarao1944',
#   'Comment_Published': '2024-03-27T02:10:00Z'},
#  {'Comment_Id': 'Ugyn5xlj7JSXgVVmBe54AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Dhoni💛',
#   'Comment_Author': '@padmavenkataramaniramani7739',
#   'Comment_Published': '2024-03-27T01:30:50Z'},
#  {'Comment_Id': 'Ugws3zjdbm_SiP8xsgh4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Dhoniamsama irukkar.',
#   'Comment_Author': '@jayadeborah1536',
#   'Comment_Published': '2024-03-26T20:54:33Z'},
#  {'Comment_Id': 'Ugy78tXw-PUuvqtSAsF4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'What a dominating win Guysss 💛',
#   'Comment_Author': '@user-we7tu6ht2b',
#   'Comment_Published': '2024-03-26T18:30:46Z'},
#  {'Comment_Id': 'Ugws-ZoJQtmIhXkkPdR4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'CSK won',
#   'Comment_Author': '@Allahkabaap2344',
#   'Comment_Published': '2024-03-26T18:04:02Z'},
#  {'Comment_Id': 'UgzQv1Ra0UletN4BTXp4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': '❤❤',
#   'Comment_Author': '@user-gn5bp8fi4l',
#   'Comment_Published': '2024-03-26T16:01:41Z'},
#  {'Comment_Id': 'UgwLD0m9Hh5niOLi22d4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'i am very eagerly waiting for Mukesh Chaudhary/Shardul Thakur.',
#   'Comment_Author': '@ragashravaniyer927',
#   'Comment_Published': '2024-03-26T15:59:08Z'},
#  {'Comment_Id': 'Ugyjvhwhci3SOjGPgc94AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'All eyes on Mohit vs jadeja 😅😍🥰👍',
#   'Comment_Author': '@user-wz9yz3cq8d',
#   'Comment_Published': '2024-03-26T15:55:42Z'},
#  {'Comment_Id': 'Ugwu6Cu9uPM2djL1ZUB4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Bad luck for rachin and rutu both got out on 46',
#   'Comment_Author': '@mr_unique672',
#   'Comment_Published': '2024-03-26T15:25:48Z'},
#  {'Comment_Id': 'Ugz7OT9LOyIJ3TzRVsR4AaABAg',
#   'video_Id': '4p-tnIPxfsY',
#   'Comment_Text': 'Bad luck for rachin and rutu both got out on 46',
#   'Comment_Author': '@mr_unique672',
#   'Comment_Published': '2024-03-26T15:25:37Z'},
#  {'Comment_Id': 'UgyVIQqLSs0eAYiewjB4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'I love CSK❤❤❤',
#   'Comment_Author': '@Bottacharen-zv4br',
#   'Comment_Published': '2024-04-02T01:49:55Z'},
#  {'Comment_Id': 'Ugwbje5UcGBkPL4-WWp4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Classic rahane❤',
#   'Comment_Author': '@soundaryahiremani329',
#   'Comment_Published': '2024-04-01T13:53:12Z'},
#  {'Comment_Id': 'Ugxma0ZJv1nyKV0QujB4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Csk🎉🎉🎉🎉',
#   'Comment_Author': '@Biranchi1448',
#   'Comment_Published': '2024-03-31T08:57:37Z'},
#  {'Comment_Id': 'UgztDPDSWezzPXMngXl4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Ruttujinx',
#   'Comment_Author': '@gaminglover8918',
#   'Comment_Published': '2024-03-30T06:15:56Z'},
#  {'Comment_Id': 'UgxIWubwr1moxSfsPdl4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Next match both will score 50 + and jinx with 200 strikerate ❤',
#   'Comment_Author': '@santoshgupta5110',
#   'Comment_Published': '2024-03-29T04:53:03Z'},
#  {'Comment_Id': 'UgyYaa4TWyRX8fSjwoR4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': '🔥🔥🔥🔥💛💛💛💛💛💛',
#   'Comment_Author': '@gopinathhari1300',
#   'Comment_Published': '2024-03-28T16:06:42Z'},
#  {'Comment_Id': 'Ugw8BmojTeH6LATiJod4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Ajju ❤',
#   'Comment_Author': '@myshorts9964',
#   'Comment_Published': '2024-03-28T12:28:59Z'},
#  {'Comment_Id': 'UgzVqEXxoXJ1NZZQdVB4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Look at the thigh pads of rahane 😢🙏',
#   'Comment_Author': '@pmvskumar307',
#   'Comment_Published': '2024-03-28T06:50:42Z'},
#  {'Comment_Id': 'UgysNKKgG-a5nUNJpm94AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'We want a great innings from rahane',
#   'Comment_Author': '@RahulSahu-co9vu',
#   'Comment_Published': '2024-03-28T03:54:38Z'},
#  {'Comment_Id': 'UgwJjkny-1aKoMfC1Wl4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Welcome',
#   'Comment_Author': '@irfancsk1681',
#   'Comment_Published': '2024-03-28T03:41:55Z'},
#  {'Comment_Id': 'UgzBpGArJ5PUgpNwSVx4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Surely who creates videos in the ongoing IPL is the best team of the IPL😂',
#   'Comment_Author': '@JustDifferent77',
#   'Comment_Published': '2024-03-28T02:44:57Z'},
#  {'Comment_Id': 'Ugw6aV1e38qbkmHEv514AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Jadeja.  Love. Like ❤',
#   'Comment_Author': '@ZALA982',
#   'Comment_Published': '2024-03-27T08:45:16Z'},
#  {'Comment_Id': 'UgyhkCNxQV_bvJRNyZN4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Guys, this CSK squad is something else! We got explosive opening pair, strong middle order batsman,lower order batsman like Rizvi hit some big sixes in. <br>We got powerplay specialist fast bowler like D.Chahar,Death over specialist like Fizz and Pathirana <br>Jadeja ,santenar, thekshana, moeen Ali on the spinning side!<br>We got <a href="http://mr.cool/">Mr.cool</a> Ms dhoni with his student and our new captain Rutu<br>Dhois experience is giving us goods in every match.<br>Who will stop this CSK?',
#   'Comment_Author': '@shubhamshinde9265',
#   'Comment_Published': '2024-03-27T04:03:36Z'},
#  {'Comment_Id': 'UgzzAufisOIF2WqfxYh4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'RRR RACHIN,RUTHU,RAHANE🤌🤌🥰🥰',
#   'Comment_Author': '@t.siddhartha8723',
#   'Comment_Published': '2024-03-27T02:26:54Z'},
#  {'Comment_Id': 'UgwOQ0mLP8JzUEw4zwN4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'I can tell who is batting without looking faces, just by the shot selection and style 👑',
#   'Comment_Author': '@ReyanshShrivastava-hh1bb',
#   'Comment_Published': '2024-03-26T19:55:07Z'},
#  {'Comment_Id': 'UgyHX5SOgk4kTz5tZWJ4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Rocking rutu classic aju 🔥🔥🔥',
#   'Comment_Author': '@ashutoshnandasonu9889',
#   'Comment_Published': '2024-03-26T13:22:21Z'},
#  {'Comment_Id': 'Ugy3nq6njVMFSGD64QN4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Look at rutu shots , I think he has had something personal with GT 😅😅',
#   'Comment_Author': '@arindazabeen3152',
#   'Comment_Published': '2024-03-26T13:06:20Z'},
#  {'Comment_Id': 'UgzPjy9vA0YSlQdPq3N4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Rutu: aaj to gt ke against khelna hai!',
#   'Comment_Author': '@anmol5517',
#   'Comment_Published': '2024-03-26T13:02:42Z'},
#  {'Comment_Id': 'Ugyb7gVPtgX0_C3J5554AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Plss, Rutu get your performance back❤❤❤',
#   'Comment_Author': '@manishmahanand742',
#   'Comment_Published': '2024-03-26T12:48:40Z'},
#  {'Comment_Id': 'UgwCN0KJZNKU77sQvnJ4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'no. 2 &amp; 3',
#   'Comment_Author': '@k_a3276',
#   'Comment_Published': '2024-03-26T12:45:06Z'},
#  {'Comment_Id': 'Ugz1plXQl3n-7qJOoK94AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Today win<br>👇',
#   'Comment_Author': '@FFKLRICHIE',
#   'Comment_Published': '2024-03-26T12:43:19Z'},
#  {'Comment_Id': 'Ugyk8WyVX4ng_gop1d54AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'CSK 🏆🏆🏆🏆🏆🏆',
#   'Comment_Author': '@chotondas781',
#   'Comment_Published': '2024-03-26T12:42:33Z'},
#  {'Comment_Id': 'UgwzU9-oZ0b4xWa04KF4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Plese Rahane Se Opening Karwa De Aaj Plese',
#   'Comment_Author': '@youtubesmall223',
#   'Comment_Published': '2024-03-26T12:38:45Z'},
#  {'Comment_Id': 'UgzbZpFIIPZYfMlj32N4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Ajju bhai 💛💛💛💛💛💛💛💛💛💛💛💛💛💛',
#   'Comment_Author': '@funhouse3165',
#   'Comment_Published': '2024-03-26T12:32:32Z'},
#  {'Comment_Id': 'UgxuDNbdXdbodv7EnkJ4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Guys practice for slower balls because Mohit Sharma has mastered it in death over',
#   'Comment_Author': '@3star_07_18',
#   'Comment_Published': '2024-03-26T12:31:15Z'},
#  {'Comment_Id': 'UgyE2EV_tr6339riFtJ4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Net practice bowlers should be also bowling difficult lengths and lines not lollipop deliveries. <br>Ruturaj and Ajinkya are such beautiful players. They should be in Indian team.',
#   'Comment_Author': '@richaneesh',
#   'Comment_Published': '2024-03-26T12:16:42Z'},
#  {'Comment_Id': 'UgyNcM1-8_pVEY8or5x4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Ravindra Jadeja',
#   'Comment_Author': '@MuhamedHashir54',
#   'Comment_Published': '2024-03-26T12:16:26Z'},
#  {'Comment_Id': 'Ugw4t60yFHm77zZMS0R4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Bat sound 💛😍',
#   'Comment_Author': '@Madanlal-ws9cq',
#   'Comment_Published': '2024-03-26T12:13:07Z'},
#  {'Comment_Id': 'Ugx0Qh7mAIjV1WbyLDZ4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Dhoni Dhoniiiiiiiiiiiiiiiiiiiiiiiiiiiiiu ❤❤❤❤❤❤❤❤❤',
#   'Comment_Author': '@bobuandsubhu6141',
#   'Comment_Published': '2024-03-26T12:11:55Z'},
#  {'Comment_Id': 'UgzVOD6fn0Zv47EyCTp4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Rahane is a great Rutu is a treat ❤',
#   'Comment_Author': '@vignesh_G7',
#   'Comment_Published': '2024-03-26T12:10:31Z'},
#  {'Comment_Id': 'UgxBXXa_ylDJ3N8F2rt4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Ajinkya always have classy shots !!! ❤....I just love his typical classic shots 😍💞💞',
#   'Comment_Author': '@user-wz9yz3cq8d',
#   'Comment_Published': '2024-03-26T12:10:13Z'},
#  {'Comment_Id': 'UgzUudG8PX77ZR906s54AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Aaj agar chennai 9 wickets se jeet jaay to💀💛',
#   'Comment_Author': '@Saurabhsinh_chaudhry',
#   'Comment_Published': '2024-03-26T12:09:53Z'},
#  {'Comment_Id': 'UgwvYKzwshKk4fRdRtx4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Looking at his preparation ,Rutu has something personal with GT😂',
#   'Comment_Author': '@RahulB-oz3wh',
#   'Comment_Published': '2024-03-26T12:09:35Z'},
#  {'Comment_Id': 'Ugx87aS7E5PBhB_nbet4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Ajju ❤',
#   'Comment_Author': '@fsxvenomop',
#   'Comment_Published': '2024-03-26T12:07:56Z'},
#  {'Comment_Id': 'UgyndI3qL6Xh2y1dsRF4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Dhoni bhai ka chela',
#   'Comment_Author': '@user-wh9ew2mo4m',
#   'Comment_Published': '2024-03-26T12:07:54Z'},
#  {'Comment_Id': 'UgxxyNLkO008o7-rwe54AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Pleas ajj tuk tuk mat karna 😔',
#   'Comment_Author': '@anupamboss6965',
#   'Comment_Published': '2024-03-26T12:07:45Z'},
#  {'Comment_Id': 'UgxCX7-jziCDKzup62J4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'ऋतुराज गायकवाड के लिए एक लाइक',
#   'Comment_Author': '@jashvantkumar8940',
#   'Comment_Published': '2024-03-26T12:04:26Z'},
#  {'Comment_Id': 'UgzX6EOhCTUayE9VH2N4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Classy shots  🔥🔥<br>Rutu fans',
#   'Comment_Author': '@Shameem795',
#   'Comment_Published': '2024-03-26T12:00:56Z'},
#  {'Comment_Id': 'UgyGddpVpwUzqADfLHF4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'csk match today ❤❤❤💛💛💛💛',
#   'Comment_Author': '@krishna-yt_995',
#   'Comment_Published': '2024-03-26T12:00:41Z'},
#  {'Comment_Id': 'UgxL98d-SgRLusiS1Fh4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Csk',
#   'Comment_Author': '@MSROFFICIAL633',
#   'Comment_Published': '2024-03-26T11:59:19Z'},
#  {'Comment_Id': 'UgwXRezZb-XtOVN0Vzd4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'RutuRaj gaykwad 60+ run and rachin first ipl fifti lagayenge 🎉🎉🎉',
#   'Comment_Author': '@MSROFFICIAL633',
#   'Comment_Published': '2024-03-26T11:59:07Z'},
#  {'Comment_Id': 'UgzKvpQKvGsP7Xnfr_F4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Rutu going big today🤞🧿🫶',
#   'Comment_Author': '@Rutika7',
#   'Comment_Published': '2024-03-26T11:58:45Z'},
#  {'Comment_Id': 'UgzskpqzSwr850HR7WJ4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'CSK win today match ❤❤❤',
#   'Comment_Author': '@MSROFFICIAL633',
#   'Comment_Published': '2024-03-26T11:57:49Z'},
#  {'Comment_Id': 'UgxWz5Re8meUptZpuId4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Always 👑👑💛💛',
#   'Comment_Author': '@_raunakeditz',
#   'Comment_Published': '2024-03-26T11:55:54Z'},
#  {'Comment_Id': 'UgzqnMdXRc0bAUTT6OZ4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': 'Thala forever ❤❤',
#   'Comment_Author': '@_raunakeditz',
#   'Comment_Published': '2024-03-26T11:55:45Z'},
#  {'Comment_Id': 'Ugx_4YhpoA6X0-rthRp4AaABAg',
#   'video_Id': 'EBhH7vCVebA',
#   'Comment_Text': '💛💛💛💛',
#   'Comment_Author': '@mohamedalhareesh.a1053',
#   'Comment_Published': '2024-03-26T11:55:39Z'},
#  ...]

# %%
#get playlist details
def get_playlist_details(channel_id):
        next_page_token=None
        Data=[]
        while True:
                request = youtube.playlists().list(
                        part='snippet,contentDetails',
                        channelId=channel_id,
                        maxResults=50,
                        pageToken=next_page_token
                )
                response=request.execute()

                for item in response['items']:
                        data=dict(Playlist_id=item['id'],
                                Title=item['snippet']['title'],
                                Channel_Id=item['snippet']['channelId'],
                                Channel_name=item['snippet']['channelTitle'],
                                PublishedAt=item['snippet']['publishedAt'],
                                Video_count=item['contentDetails']['itemCount'])
                        
                        Data.append(data)

                next_page_token=response.get('nextPageToken') 
                if next_page_token is None:
                        break 

                
        return Data

# %%
get_playlist_details("UC2J_VKrAzOEJuQvFFtj3KUw")
# Out:
# [{'Playlist_id': 'PL7GssaCNTMlkTSuQvSmc6QHhSG_3vBv3r',
#   'Title': 'Whistles from Chepauk - CWC 2023',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2023-11-02T05:47:29Z',
#   'Video_count': 5},
#  {'Playlist_id': 'PL7GssaCNTMlljlbRj9I2y_Yuv71aMoHMn',
#   'Title': 'Cricket with Badri - CWC 2023',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2023-11-02T05:43:57Z',
#   'Video_count': 4},
#  {'Playlist_id': 'PL7GssaCNTMlmMDJBkpdDn-CcjXFuq0rxI',
#   'Title': 'Gripping Stories',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2022-07-22T11:26:35Z',
#   'Video_count': 2},
#  {'Playlist_id': 'PL7GssaCNTMlmyqaq_HjLIgyiIbSe9OmjQ',
#   'Title': 'Team Mates',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2022-07-22T11:21:15Z',
#   'Video_count': 3},
#  {'Playlist_id': 'PL7GssaCNTMlltZdJFQ6ONWdmFILDPzomS',
#   'Title': 'First Time in Yellove - 2022',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2022-04-10T19:10:34Z',
#   'Video_count': 9},
#  {'Playlist_id': 'PL7GssaCNTMlnIpq7uDNVruyU__KmBP9Gy',
#   'Title': 'Candid Super Kings - 2022',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2022-04-10T19:07:34Z',
#   'Video_count': 1},
#  {'Playlist_id': 'PL7GssaCNTMlnNRqa12s7p51x6uI9yNiNO',
#   'Title': 'Super Practice - 2022',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2022-04-10T19:07:14Z',
#   'Video_count': 1},
#  {'Playlist_id': 'PL7GssaCNTMlltI4ObEFO_KyzzCIlBuhVL',
#   'Title': 'Anbuden Diaries - 2022',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2022-04-10T19:06:15Z',
#   'Video_count': 2},
#  {'Playlist_id': 'PL7GssaCNTMlkBJu0aMuMw1Oq409odv0q6',
#   'Title': 'Post Match 2022',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2022-04-10T18:50:28Z',
#   'Video_count': 4},
#  {'Playlist_id': 'PL7GssaCNTMll3CZy_6H2RvNJ83o0NvLhn',
#   'Title': 'Super Auction 2022',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2022-02-11T12:23:58Z',
#   'Video_count': 4},
#  {'Playlist_id': 'PL7GssaCNTMlkZbFDiTvhcxmDBzR3RNYjU',
#   'Title': 'Super Fans',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T07:39:15Z',
#   'Video_count': 1},
#  {'Playlist_id': 'PL7GssaCNTMlkPDzG_3_n4YYGHr48Y3jJa',
#   'Title': 'Everywhere We Go',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T07:37:02Z',
#   'Video_count': 1},
#  {'Playlist_id': 'PL7GssaCNTMlla9utBgjzg44-qtpE6IF4k',
#   'Title': 'Super Fam Super Fun',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T07:34:39Z',
#   'Video_count': 1},
#  {'Playlist_id': 'PL7GssaCNTMlkA1w-zWCeNe5CS_OY24esp',
#   'Title': 'CubG Squad',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T07:31:11Z',
#   'Video_count': 1},
#  {'Playlist_id': 'PL7GssaCNTMllUTj8cdOPZyxZ3f1fnx4qS',
#   'Title': 'Super Couple - 2021',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T03:59:27Z',
#   'Video_count': 6},
#  {'Playlist_id': 'PL7GssaCNTMlmMho_iVGWCCvg8_00bcy95',
#   'Title': 'Super Coach',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T03:58:34Z',
#   'Video_count': 2},
#  {'Playlist_id': 'PL7GssaCNTMlmzmd5KygjwC7Dmya11MaRc',
#   'Title': 'Super Birthday',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T03:57:57Z',
#   'Video_count': 10},
#  {'Playlist_id': 'PL7GssaCNTMlk64TPwWDpIfU_7wfYIQ_CY',
#   'Title': 'Style Quotient',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-11-03T03:53:09Z',
#   'Video_count': 4},
#  {'Playlist_id': 'PL7GssaCNTMlnFGn9inw_5wrbXSKGryctj',
#   'Title': 'The Pride of 2021',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-10-29T06:12:02Z',
#   'Video_count': 29},
#  {'Playlist_id': 'PL7GssaCNTMlnnF5y3MAgCTua9HlrZnhle',
#   'Title': "What's On Your Screen",
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-04-12T08:46:41Z',
#   'Video_count': 2},
#  {'Playlist_id': 'PL7GssaCNTMllbsBhk5n2mo-1CqH7ls-wG',
#   'Title': 'AnbuDen Diaries',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-04-12T06:52:45Z',
#   'Video_count': 1},
#  {'Playlist_id': 'PL7GssaCNTMll7PMPcuCN3ErR8JfejaHne',
#   'Title': 'Post Match Round-Up',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-04-11T10:51:02Z',
#   'Video_count': 3},
#  {'Playlist_id': 'PL7GssaCNTMlk6HTrxzImX_bM_xvhdLpGI',
#   'Title': 'Pre Match Build Up',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-04-10T06:25:12Z',
#   'Video_count': 3},
#  {'Playlist_id': 'PL7GssaCNTMlmdBzUZKWnUJGTE5KyYCeWL',
#   'Title': 'Picture Perfect',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-04-09T10:33:04Z',
#   'Video_count': 2},
#  {'Playlist_id': 'PL7GssaCNTMlkvoAraB-KbsWAEvOGIB3S3',
#   'Title': 'KINGS ARENA',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-04-08T11:24:44Z',
#   'Video_count': 4},
#  {'Playlist_id': 'PL7GssaCNTMlkrtMv5D6W8qY84bM54M7cw',
#   'Title': 'Super Auction 2021!',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2021-02-21T15:01:38Z',
#   'Video_count': 8},
#  {'Playlist_id': 'PL7GssaCNTMlmolU8thAvM7wPBdPGIgBBQ',
#   'Title': 'Super Local Challenge',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2020-10-15T05:51:21Z',
#   'Video_count': 7},
#  {'Playlist_id': 'PL7GssaCNTMlmGgeU_prRPrhh9JXTI2cjO',
#   'Title': 'With Yellove!',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2020-09-16T03:20:16Z',
#   'Video_count': 7},
#  {'Playlist_id': 'PL7GssaCNTMlmu5ROjSLJ6Iiizs_WsyYIH',
#   'Title': 'AnbuDen Lions',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2020-04-15T17:35:22Z',
#   'Video_count': 15},
#  {'Playlist_id': 'PL7GssaCNTMllSsa0TLdWKSDjLtnhvUYjU',
#   'Title': 'Deepavali Release',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2019-10-27T02:02:19Z',
#   'Video_count': 1},
#  {'Playlist_id': 'FL2J_VKrAzOEJuQvFFtj3KUw',
#   'Title': 'Favorites',
#   'Channel_Id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Channel_name': 'Chennai Super Kings',
#   'PublishedAt': '2011-04-20T15:27:52Z',
#   'Video_count': 1}]

# %%
def channel_details(channel_id):
    ch_details=get_channel_info(channel_id)
    pl_details=get_playlist_details(channel_id)
    vi_ids=get_videos_ids(channel_id)
    vi_details=get_video_info(vi_ids)
    com_details=get_comment_info(vi_ids)

    coll1=db["channel_details"]
    coll1.insert_one({"channel_information":ch_details,"playlist_information":pl_details,
                      "video_information":vi_details,"comment_information":com_details})
    return "upload completed successfully"

# %%
insert=channel_details("UC2J_VKrAzOEJuQvFFtj3KUw")

# %%
insert=channel_details("UCp10aBPqcOeBbEg7d_K9SBw")

# %%
insert=channel_details("UCl23mvQ3321L7zO6JyzhVmg")

# %%
insert=channel_details("UCCq1xDJMBRF61kiOgU90_kw")

# %%
insert=channel_details("UCCBe9iIoN9Ar-Elluxca-Xw")

# %%
insert=channel_details("UCvRa1LWA_-aARq1AQMC4AyA")

# %%
insert=channel_details("UCkpgyRmcNy-aZFLUkKkWK4w")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 insert=channel_details("UCkpgyRmcNy-aZFLUkKkWK4w")
#
# Cell In[28], line 2, in channel_details(channel_id)
#       1 def channel_details(channel_id):
# ----> 2     ch_details=get_channel_info(channel_id)
#       3     pl_details=get_playlist_details(channel_id)
#       4     vi_ids=get_videos_ids(channel_id)
#
# Cell In[6], line 10, in get_channel_info(channel_id)
#       7 response = request.execute()
#       9 for i in response['items']:
# ---> 10    data = dict(Channel_Name =i['snippet']['title'],
#      11                Channel_id =i['id'],
#      12                Subscribers =i['statistics']['subscriberCount'],
#      13                Views =i['statistics']['viewCount'],
#      14                Total_Videos =i['statistics']['videoCount'],
#      15                Channel_Descripition =i['snippet']['description'],
#      16                Playlist_id =i['contentDetails']['relatedPlaylists']['uploads'])
#      18    return data
#
# KeyError: 'title'

# %%
insert=channel_details("UCScgEv0U9Wcnk24KfAzGTXg")

# %%
#table creation 

def channels_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="saran",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()


    drop_query='''drop table if exists channels'''
    cursor.execute(drop_query)
    mydb.commit()

    try:
        create_query='''create table if not exists channels(Channel_Name varchar(100),
                                                        Channel_id varchar(80) primary key,
                                                        Subscribers bigint,
                                                        Views bigint,
                                                        Total_Videos int,
                                                        Channel_Descripition text,
                                                        Playlist_id varchar(80))'''
        
        cursor.execute(create_query)
        mydb.commit()

    except:
        print("channels table already created")


    ch_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    df=pd.DataFrame(ch_list) 



    for index,row in df.iterrows():
        insert_query='''insert into channels(Channel_Name,     
                                            Channel_id ,
                                            Subscribers,
                                            Views,
                                            Total_Videos,
                                            Channel_Descripition,
                                            Playlist_id)
                                            
                                            values(%s,%s,%s,%s,%s,%s,%s)'''
        
        values=(row['Channel_Name'],
                row['Channel_id'],
                row['Subscribers'],
                row['Views'],
                row['Total_Videos'],
                row['Channel_Descripition'],
                row['Playlist_id'])
        
        try:
            cursor.execute(insert_query,values)
            mydb.commit()

        except:
            print("channels values are inserted")

# %%
def playlist_tables():
    mydb=psycopg2.connect(host="localhost",
                            user="postgres",
                            password="saran",
                            database="youtube_data",
                            port="5432")
    cursor=mydb.cursor()


    drop_query='''drop table if exists playlists'''
    cursor.execute(drop_query)
    mydb.commit()


    create_query='''create table if not exists playlists(Playlist_id varchar(100),
                                                            Title varchar(100) primary key,
                                                            Channel_Id varchar(100),
                                                            Channel_name varchar(100),
                                                            PublishedAt timestamp,
                                                            Video_count int
                                                            )'''

            
    cursor.execute(create_query)
    mydb.commit()

# %%
def videos_tables():
    mydb=psycopg2.connect(host="localhost",
                                user="postgres",
                                password="saran",
                                database="youtube_data",
                                port="5432")
    cursor=mydb.cursor()


    drop_query='''drop table if exists videos'''
    cursor.execute(drop_query)
    mydb.commit()


    create_query = '''create table if not exists videos(Channel_name varchar(100),
                                                    Channel_Id varchar(100),
                                                    Video_Id varchar(30) primary key,
                                                    Title varchar(150),
                                                    Tags text,
                                                    Thumbnail varchar(150),
                                                    Description text,
                                                    Published_Data timestamp,
                                                    Duration interval,
                                                    Views bigint,
                                                    Likes bigint,
                                                    Comments int,
                                                    Favorite_Count int,
                                                    Definition varchar(10),
                                                    Caption_Status varchar(50) 
                                                        )'''

    cursor.execute(create_query)
    mydb.commit()


    vi_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
            for i in range(len(vi_data["video_information"])):
                vi_list.append(vi_data["video_information"][i])

    df2=pd.DataFrame(vi_list) 





    for index,row in df2.iterrows():
            insert_query='''insert into channels(Channel_name ,
                                                Channel_Id,
                                                Video_Id,
                                                Title,
                                                Tags,
                                                Thumbnail,
                                                Description,
                                                Published_Data,
                                                Duration,
                                                Views,
                                                Likes,
                                                Comments,
                                                Favorite_Count,
                                                Definition,
                                                Caption_Status 
                                                )
                                                
                                                values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''

                




            values=(row['Channel_Name'],
                    row['Channel_Id'],
                    row['Video_id'],
                    row['Title'],
                    row['Tags'],
                    row['Thumbnail'],
                    row['Descripition'],
                    row['Published_Dates'],
                    row['Duration'],
                    row['Views'],
                    row['comments'],
                    row['Favorite_Count'],
                    row['Definition'],
                    row['Caption_status']
                    )
            
            
            try:
                cursor.execute(insert_query,values)
                mydb.commit()

            except:
                print("channels values are inserted")

# %%
def comments_table():
    mydb=psycopg2.connect(host="localhost",
                                user="postgres",
                                password="saran",
                                database="youtube_data",
                                port="5432")
    cursor=mydb.cursor()


    drop_query='''drop table if exists comments'''
    cursor.execute(drop_query)
    mydb.commit()


    create_query='''create table if not exists comments(Comment_Id varchar(100),
                                                        video_Id varchar(50), 
                                                        Comment_Text text,
                                                        Comment_Author varchar(150),
                                                        Comment_Published timestamp
                                                                )'''

                
    cursor.execute(create_query)
    mydb.commit()


    com_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for com_data in coll1.find({},{"_id":0,"comment_information":1}):
                for i in range(len(com_data["comment_information"])):
                    com_list.append(com_data["comment_information"][i])

    df4=pd.DataFrame(com_list) 



    for index,row in df4.iterrows():
                insert_query='''insert into comments(Comment_Id,
                                                    video_Id, 
                                                    Comment_Text,
                                                    Comment_Author,
                                                    Comment_Published 
                                            )  
                                                    
                                                    values(%s,%s,%s,%s,%s)'''

                    

        

                values=(row['Comment_Id'],
                        row['video_Id'],
                        row['Comment_Text'],
                        row['Comment_Author'],
                        row['Comment_Published']
                        
                        )
                
                
                
    cursor.execute(insert_query,values)
    mydb.commit()

# %%
def tables():
    channels_table()
    playlist_tables()
    videos_tables()
    comments_table() 

    return "Tables Created successfully"

# %%
def show_channels_table():
    ch_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
                        for i in range(len(ch_data["channel_information"])):
                            ch_list.append(ch_data["channel_information"][i])

    df=st.dataframe(ch_list) 

    return df

# %%
def show_playlist_table():
    pl_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
                    for i in range(len(pl_data["playlist_information"])):
                        pl_list.append(pl_data["playlist_information"][i])

    df3=st.dataframe(pl_list) 

    return df3

# %%
def show_videos_table():
        vi_list=[]
        db=client["youtube_data"]
        coll1=db["channel_details"]
        for vi_data in coll1.find({},{"_id":0,"video_information":1}):
                    for i in range(len(vi_data["video_information"])):
                        vi_list.append(vi_data["video_information"][i])

        df2=st.dataframe(vi_list) 

        return df2

# %%
def show_comment_table():
    com_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for com_data in coll1.find({},{"_id":0,"comment_information":1}):
                    for i in range(len(com_data["comment_information"])):
                        com_list.append(com_data["comment_information"][i])

    df4=st.dataframe(com_list) 

    return df4

# %%
#streamlit

with st.sidebar:
    st.title(":blue[YOUTUBE DATA HARVESTING AND WARHOUSEING]")
    st.header("skill take away")
    st.caption("python scriptting")
    st.caption("data collection")
    st.caption("mongodb")
    st.caption("API integration")
    st.caption("data management using mongodb and Sql")

channel_id=st.text_input("enter the channel ID")    

if st.button("collect and store data"):
    ch_ids=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
       ch_ids.append(ch_data["channel_information"]["Channel_id"])


    if channel_id in ch_ids:
        st.success("channel details of given channel id already exists")

    else:
        insert=channel_details(channel_id)
        st.success(insert)

if st.button("migrate to Sql"):
    Table=tables()
    st.success(Table)  

show_table=st.radio("SELECT THE TABLE FOR VIEW",("CHANNELS","PLAYLIST","VIDEOS","COMMENTS"))  

if show_table=="CHANNELS":
    show_channels_table()

elif show_table=="PLAYLIST":
    show_playlist_table()  

elif show_table=="VIDEOS":
    show_videos_table() 

elif show_table=="COMMENTS":
    show_comment_table()
# Out:
# 2024-04-03 14:21:00.044
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 36
#      33 show_table=st.radio("SELECT THE TABLE FOR VIEW",("CHANNELS","PLAYLIST","VIDEOS","COMMENTS"))
#      35 if show_table=="CHANNELS":
# ---> 36     show_channels_table()
#      38 elif show_table=="PLAYLIST":
#      39     show_playlist_table()
#
# Cell In[26], line 7, in show_channels_table()
#       5 for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
#       6                     for i in range(len(ch_data["channel_information"])):
# ----> 7                         ch_list.append(ch_data["channel_information"][i])
#       9 df=st.dataframe(ch_list)
#      11 return df
#
# KeyError: 0

# %%
#Sql connection
mydb=psycopg2.connect(host="localhost",
                                user="postgres",
                                password="saran",
                                database="youtube_data",
                                port="5432")
cursor=mydb.cursor()


question=st.selectbox("select your questions",("1. All the videos and the channelname",
                                               "2. channels with most number of videos",
                                               "3. 10 most viewed videos",
                                               "4. comments in each videos",
                                               "5. videos with higest likes",
                                               "6. likes and dislike of all videos",
                                               "7. views of each channel",
                                               "8. videos published in the year of 2022",
                                               "9. average duration of all videos in each channel",
                                               "10. videos with highest number of comments"))


if question=="1.All the videos and the channelname":
    query1='''select title as videos,channel_name as channelname from videos'''
    cursor.execute(query1)
    mydb.commit()
    t1=cursor.fetchall()
    df=pd.DataFrame(t1,columns=["video title","channel name"])
    st.write(df)


elif question=="1.channels with most number of videos":
    query2='''select channel_name as channelname,total_videos as no_videos from channels
            order by total_videos desc'''
    cursor.execute(query2)
    mydb.commit()
    t2=cursor.fetchall()
    df=pd.DataFrame(t2,columns=["channel name","no of videos"])
    st.write(df)


elif question=="3. 10 most viewed videos":
    query3='''select views as views,channel_name as channelname,title as videotitle from videos
            where views is not null order by views desc limit 10'''
    cursor.execute(query3)
    mydb.commit()
    t3=cursor.fetchall()
    df3=pd.DataFrame(t3,columns=["views","channelname","videotitle"])
    st.write(df3)


elif question=="4. comments in each videos":
    query4='''select comments as no_comments,title as videotitle from videos where comment is not null'''
    cursor.execute(query4)
    mydb.commit()
    t4=cursor.fetchall()
    df4=pd.DataFrame(t4,columns=["no of comments","vieotitle"])
    st.write(df4)


elif question=="5. videos with higest likes":
    query5='''select title as video title,channel_names as channelname,like as likecount
                from videos where like is not null order by likes desc'''
    cursor.execute(query5)
    mydb.commit()
    t5=cursor.fetchall()
    df5=pd.DataFrame(t5,columns=["video title","channel name"])
    st.write(df5)

elif question=="6. likes and dislike of all videos":
    query6='''select likes as likecount,tile as videotitle from videos'''
    cursor.execute(query6)
    mydb.commit()
    t6=cursor.fetchall()
    df6=pd.DataFrame(t6,columns=["likecount","videotitle"])
    st.write(df6)

elif question=="7. views of each channel":
    query7='''select channel_name as channelname,views as totalviews from channels'''
    cursor.execute(query7)
    mydb.commit()
    t7=cursor.fetchall()
    df7=pd.DataFrame(t7,columns=["channelname","totalviews"])
    st.write(df7)

elif question=="8. videos published in the year of 2022":
    query8='''select title as video_title,published_date as videorelease,channel_name as channelname from videos
                where extract(year from published_date)=2022'''
    cursor.execute(query8)
    mydb.commit()
    t8=cursor.fetchall()
    df8=pd.DataFrame(t8,columns=["",""])
    st.write(df8)

elif question=="9. average duration of all videos in each channel":
    query9='''select channel_name as channelname,AVG(duration) as averagedurationfrom videos group by channel_name'''
    cursor.execute(query9)
    mydb.commit()
    t9=cursor.fetchall()
    df9=pd.DataFrame(t9,columns=["channelname","averageduration"])
    st.write(df9)

    T9=[]
    for index,row in df9.iterrows():
        channel_title=row['channelname']
        average_duration=row['averageduration']
        average_duration_str=str(average_duration)
        T9.append(dict(channeltile=channel_title,avgduration=average_duration_str))
    df1=pd.DataFrame(T9)

elif question=="10. videos with highest number of comments":
    query10='''select title as videotitle,channel_name as channelname,comments as cmments from videos where comments is
                not null order by comments desc'''
    cursor.execute(query10)
    mydb.commit()
    t10=cursor.fetchall()
    df10=pd.DataFrame(t10,columns=["videotitle","channel name","comments"])
    st.write(df10)
